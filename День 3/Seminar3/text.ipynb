# %% [markdown]
# # Работа с текстами на русском языке

# %% [markdown]
# В языках мира существуют две основных группы способов выражения грамматических значений:
#
# - синтетические способы
# - аналитические способы
#
# Для **синтетических способов** характерно соединение грамматического показателя с самим словом. Таким показателем, вносящим грамматическое значение ≪внутрь слова≫, могут быть окончание, суффикс, приставка, внутренняя флексия и т.д.
#
# Общей чертой **аналитических способов** является выражение грамматического значения за пределами слова, отдельно от него — например, с помощью предлогов, союзов, артиклей, вспомогательных глаголов и других служебных слов, а также с помощью порядка слов.
#
# Существеное отличие в работе с русским и английским текстом заключается в том, что для русского языка более хврактерен синтетический способ, а для английского -- аналитический.

# %% [markdown]
# ### Постановка задачи
#
# При работе с большим объёмом данных важно поддерживать их чистоту. А при заполнении заявки на банковский продукт необходимо указывать полные паспортные данные, в том числе и поле «кем выдан паспорт», число различных вариантов написаний одного и того же отделения потенциальными клиентами может достигать нескольких сотен. Важно понимать, не ошибся ли клиент, заполняя другие поля: «код подразделения», «серию/номер паспорта». Для этого необходимо сверять «код подразделения» и «кем выдан паспорт».
# Задача заключается в том, чтобы проставить коды подразделений для записей из тестовой выборки, основываясь на обучающей выборке.
#
# https://habr.com/ru/post/205360/

# %% [markdown]
# #### Предварительная обработка данных
#
# Загрузим данные и посмотрим, что мы имеем:

# %%
from pandas import read_csv
import pymorphy2
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.decomposition import PCA

train = read_csv('https://static.tcsbank.ru/documents/olymp/passport_training_set.csv',';', index_col='id' ,encoding='cp1251')
train.head(5)
# Out:
#     passport_div_code                               passport_issuer_name  \
# id
# 1              422008                  БЕЛОВСКИМ УВД КЕМЕРОВСКОЙ ОБЛАСТИ
# 2              500112  ТП №2 В ГОР. ОРЕХОВО-ЗУЕВО ОУФМС РОССИИ ПО МО ...
# 3              642001                         ВОЛЖСКИМ РОВД ГОР.САРАТОВА
# 4              162004                    УВД МОСКОВСКОГО РАЙОНА Г.КАЗАНЬ
# 5               80001    ОТДЕЛОМ ОФМС РОССИИ ПО РЕСП КАЛМЫКИЯ В Г ЭЛИСТА
#
#    passport_issue_month/year
# id
# 1                    11M2001
# 2                    03M2009
# 3                    04M2002
# 4                    12M2002
# 5                    08M2009

# %% [markdown]
# Теперь можно посмотреть как пользователи записывают поле «кем выдан паспорт» на примере какого-либо подразделения:

# %%
example_code = train.passport_div_code[train.passport_div_code.duplicated()].values[0]
for i in train.passport_issuer_name[train.passport_div_code == example_code].drop_duplicates():
    print(i)
# Out:
# ОТДЕЛЕНИЕМ УФМС РОССИИ ПО РЕСПУБЛИКЕ КАРЕЛИЯ В МЕДВЕЖ. Р-Е
# ОТДЕЛЕНИЕМ УФМС РОССИИ ПО Р. КАРЕЛИЯ В МЕДВЕЖЬЕГОРСКОМ РАЙОНЕ
# ОТДЕЛЕНИЕМ УФМС РОССИИ ПО РЕСП КАРЕЛИЯ В МЕДВЕЖЬЕГОРСКОМ Р-НЕ
# ОТДЕЛЕНИЕМ УФМС РОССИИ ПО РЕСПУБЛИКЕ КАРЕЛИЯ В МЕДВЕЖЬЕГОРСКОМ РАЙОНЕ
# ОУФМС РОССИИ ПО РЕСПУБЛИКЕ КАРЕЛИЯ В МЕДВЕЖЬЕГОРСКОМ РАЙОНЕ
# УФМС РОССИИ ПО РК В МЕДВЕЖЬЕГОРСКОМ РАЙОНЕ
# ОТДЕЛЕНИЕМ УФМС РОССИИ ПО РЕСПУБЛИКЕ КАРЕЛИЯ МЕДВЕЖЬЕГОРСКОМ Р-ОНЕ
# ОТДЕЛЕНИЕМ УФМС РОССИИ ПО РК В МЕДВЕЖЬЕГОРСКОМ РАЙОНЕ
# ОТДЕЛЕНИЕМ УФМС РОССИИ ПО РЕСПУБЛИКЕ КОРЕЛИЯ В МЕДВЕЖИГОРСКОМ РАЙОНЕ
# УФМС РОССИИ ПО Р. КАРЕЛИЯ МЕДВЕЖЬЕГОРСКОГО Р-НА
# ОТДЕЛОМ УФМС РОССИИ ПО РЕСПУБЛИКЕ КАРЕЛИЯ В МЕДВЕЖЬЕГОРСКОМ
# УФМС РЕСПУБЛИКИ КАРЕЛИИ МЕДВЕЖЬЕГОРСКОГО Р-ОН
# МЕДВЕЖЬЕГОРСКИМ ОВД

# %% [markdown]
# Как можно заметить нужно на поле действительно заполняется криво. Но для нормально кодирования мы должны привести это поле к более-менее нормальному (однозначному) виду.
# Для начала я бы предложил привести все записи к одному регистру, например, чтобы все буквы стали строчными. Это легко сделать с помощью атрибута str, столбца DataFrame'a. Этот атрибут позволяет работать со столбцом как с строкой, а также выполнять различного рода поиск и замену по регулярным выражениям:

# %%
train.passport_issuer_name = train.passport_issuer_name.str.lower()
train[train.passport_div_code == example_code].head(5)
# Out:
#       passport_div_code                               passport_issuer_name  \
# id
# 19               100010  отделением уфмс россии по республике карелия в...
# 22               100010  отделением уфмс россии по р. карелия в медвежь...
# 5642             100010  отделением уфмс россии по респ карелия в медве...
# 6668             100010  отделением уфмс россии по республике карелия в...
# 8732             100010  отделением уфмс россии по республике карелия в...
#
#      passport_issue_month/year
# id
# 19                     04M2008
# 22                     10M2009
# 5642                   08M2008
# 6668                   08M2011
# 8732                   08M2012

# %% [markdown]
# C регистром определились. Далее надо по возможности избавиться от популярных сокращений, например район, город и т.д. Сделаем это с помощью регулярных выражений. Pandas предоставляет удобное использование регулярных выражений применительно к каждому столбцу. Это выглядит так:

# %%
train.passport_issuer_name = train.passport_issuer_name.str.replace(u'р-(а|й|о|н|е)*',u'район')
train.passport_issuer_name = train.passport_issuer_name.str.replace(u' г( |\.|(ор(\.| )))', u' город ')
train.passport_issuer_name = train.passport_issuer_name.str.replace(u' р(\.|есп )', u' республика ')
train.passport_issuer_name = train.passport_issuer_name.str.replace(u' адм([а-я]*)(\.)?', u' административный ')
train.passport_issuer_name = train.passport_issuer_name.str.replace(u' окр(\.| |уга( )?)', u' округ ')
train.passport_issuer_name = train.passport_issuer_name.str.replace(u' ао ', u' административный округ ')

# %% [markdown]
# Теперь избавимся от всех лишних символов, кроме русских букв, дефисов и пробелов. Это связано с тем, что паспорт о одинаковым подразделением может выдаваться отделами с разными номерами, и это ухудшит дальнейшую кодировку:

# %%
train.passport_issuer_name = train.passport_issuer_name.str.replace(u' - ?', u'-')
train.passport_issuer_name = train.passport_issuer_name.str.replace(u'[^а-я -]','')
train.passport_issuer_name = train.passport_issuer_name.str.replace(u'- ',' ')
train.passport_issuer_name = train.passport_issuer_name.str.replace(u'  *',' ')

# %% [markdown]
# На следующем шаге, надо расшифровать аббревиатуры, типа УВД, УФНС, ЦАО, ВАО и т.д., т.к. этих их в принципе не много, но на качестве дальнейшего кодирования это скажется положительно. Например если у нас будет две записи «УВД» и «управление внутренних дел», то закодированы они будут по разному, т. к. для компьютера это разные значения.
# Итак перейдем к расшифровке. И, для начала, заведем словарь сокращений, с помощью которого мы и сделаем расшифровку:

# %%
sokr = {u'нао': u'ненецкий автономный округ',
u'хмао': u'ханты-мансийский автономный округ',
u'чао': u'чукотский автономный округ',
u'янао': u'ямало-ненецкий автономный округ',
u'вао': u'восточный административный округ',
u'цао': u'центральный административный округ',
u'зао': u'западный административный округ',
u'cао': u'северный административный округ',
u'юао': u'южный административный округ',
u'юзао': u'юго-западный округ',
u'ювао': u'юго-восточный округ',
u'свао': u'северо-восточный округ',
u'сзао': u'северо-западный округ',
u'оуфмс': u'отдел управление федеральной миграционной службы',
u'офмс': u'отдел федеральной миграционной службы',
u'уфмс': u'управление федеральной миграционной службы',
u'увд': u'управление внутренних дел',
u'ровд': u'районный отдел внутренних дел',
u'говд': u'городской отдел внутренних дел',
u'рувд': u'районное управление внутренних дел',
u'овд': u'отдел внутренних дел',
u'оувд': u'отдел управления внутренних дел',
u'мро': u'межрайонный отдел',
u'пс': u'паспортный стол',
u'тп': u'территориальный пункт'}

# %% [markdown]
# Теперь, собственно произведем расшифровку абривеатур и отформатируем полученные записи:

# %%
for key in sokr:
    train.passport_issuer_name = train.passport_issuer_name.str.replace(u'( %s )|(^%s)|(%s$)' % (i,i,i), u' %s ' % (sokr[key]))
    
#удалим лишние пробелы в конце и начале строки
train.passport_issuer_name = train.passport_issuer_name.str.lstrip()
train.passport_issuer_name = train.passport_issuer_name.str.rstrip()

# %% [markdown]
# Предварительный этап обработки поля «кем выдан паспорт» на этом закончим. И перейдем к полю, в котором находится дата выдачи.
# Как можно заметить данные в нем хранятся в виде: месяцMгод.
# Соответственно можно просто убрать букву «M» и привести поле к числовому типу. Но если хорошо подумать, то это поле можно удалить, т.к. на один месяц в году может приходиться несколько подразделений выдававших паспорт, и соответственно это может испортить нашу модель. Исходя из этого удалим его из выборки:

# %%
train = train.drop(['passport_issue_month/year'], axis=1)

# %% [markdown]
# #### Анализ данных

# %% [markdown]
# Итак, данные для построения модели у нас есть, но они находятся в текстовом виде. Для построения модели хорошо бы было их закодировать в числовом виде.
#
# Авторы пакета scikit-learn заботливо о нас позаботились и добавили несколько способов для извлечения и кодирования текстовых данных:
#
# - FeatureHasher
# - CountVectorizer
# - HashingVectorizer
#
# **FeatureHasher** преобразовывает строку в числовой массив заданной длинной с помощью хэш-функции (32-разрядная версия Murmurhash3)
#
# **CountVectorizer** преобразовывает входной текст в матрицу, значениями которой, являются количества вхождения данного ключа(слова) в текст. В отличие от FeatureHasher имеет больше настраиваемых параметров(например можно задать токенизатор), но работает медленнее.
#
# **HashingVectorizer** является смесью двух выше описанных методов. В нем можно и регулировать размер закодированной строки (как в FeatureHasher) и настраивать токенизатор (как в CountVectorizer). К тому же его производительность ближе к FeatureHasher.

# %% [markdown]
# Для начала CountVectorizer собирает уникальные ключи из всех записей.
#
# Длина списка из уникальных ключей и будет длиной нашего закодированного текста. А номера элементов будут соответствовать, количеству раз встречи данного ключа с данным номером в строке.
#
# **Пример:**
#
# Дано:
# - раз два три
# - три четыре два два
# - раз раз раз четыре
#
# Список уникальных ключей: [раз, два, три, четыре]
#
# - раз два три --> [1,1,1,0]
# - три четыре два два --> [0,2,1,1]

# %% [markdown]
# Итак, вернемся к анализу. Если мы посмотрим по внимательнее на наш набор данных то можно заметить, что есть похожие строки но записанные по разному например: "… республика карелия..." и "… по республике карелия...".
#
# Соответственно, если мы попробуем применить один из методов кодирования сейчас мы получим очень похожие значения. Такие случаем можно минимизировать если все слова в записи мы приведем к нормальной форме.
#
# Для этой задачи хорошо подходит pymorphy или nltk. Я буду использовать первый, т.к. он изначально создавался для работы с русским языком. Итак, функция которая будет отвечать за нормализацию и очиску строки выглядит так:

# %%
def f_tokenizer(s):
    morph = pymorphy2.MorphAnalyzer()
    if type(s) == "unicode":
        t = s.split(' ')
    else:
        t = s
    f = []
    for j in t:
        m = morph.parse(j.replace('.',''))
        if len(m) != 0:
            wrd = m[0]
            if wrd.tag.POS not in ('NUMR','PREP','CONJ','PRCL','INTJ'):
                f.append(wrd.normal_form)
    return(f)

# %% [markdown]
# Функция делает следующее:
# - Сначала она преобразовывает строку в список
# - Затем для всех слов производит разбор
# - Если слово является числительным, предикативном, предлогом, союзом, частицей или междометием не включаем его в конечный набор
# - Если слово не попало в предыдущий список, берем его нормальную форму и добавляем в финальный набор
#
# Теперь, когда есть функция для нормализации можно приступить к кодированию с помощью метода CountVectorizer. Он выбран потому, что ему можно передать нашу функцию, как токенизатор и он составит список ключей по значениям полученным в результате работы нашей функции:

# %%
coder = HashingVectorizer(tokenizer=f_tokenizer, n_features=256)

# %% [markdown]
# Как можно заметить при создании метода кроме токенизатора мы задаем еще один параметр n_features. Через данный параметр задается длина закодированной строки (в нашем случае строка кодируется при помощи 256 столбцов). Кроме того, у HashingVectorizer есть еще одно преимущество перед CountVectorizer, но сразу может выполнять нормализацию значений, что хорошо для таких алгоритмов, как SVM.
# Теперь применим наш кодировщик к обучающему набору:

# %%
TrainNotDuble = train.drop_duplicates()
trn = coder.fit_transform(TrainNotDuble.passport_issuer_name.tolist()).toarray()

# %% [markdown]
# #### Построение модели
#
# Для начала нам надо задать значения для столбца, в котором будут содержаться метки классов:

# %%
target = TrainNotDuble.passport_div_code.values

# %%
pca = PCA(n_components = 15)
trn = pca.fit_transform(trn)

# %%
model = RandomForestClassifier(n_estimators = 100, criterion='entropy')

TRNtrain, TRNtest, TARtrain, TARtest = train_test_split(trn, target, test_size=0.4)
model.fit(TRNtrain, TARtrain)
print('accuracy_score: ', accuracy_score(TARtest, model.predict(TRNtest)))
# Out:
# accuracy_score:  0.7379523720232515

# %% [markdown]
# # Анализ тональности текстов с помощью сверточных нейронных сетей

# %% [markdown]
# <img width=600 src="net.gif">
# https://habr.com/ru/company/mailru/blog/417767/

# %% [markdown]
# Представьте, что у вас есть абзац текста. Можно ли понять, какую эмоцию несет этот текст: радость, грусть, гнев? Можно. Упростим себе задачу и будем классифицировать эмоцию как позитивную или как негативную, без уточнений. Есть много способов решать такую задачу, и один из них — свёрточные нейронные сети (Convolutional Neural Networks). CNN изначально были разработаны для обработки изображений, однако они успешно справляются с решением задач в сфере автоматической обработки текстов.

# %% [markdown]
# Для обучения я выбрал корпус коротких текстов Юлии Рубцовой, сформированный на основе русскоязычных сообщений из Twitter. Он содержит 114 991 положительных, 111 923 отрицательных твитов, а также базу неразмеченных твитов объемом 17 639 674 сообщений.

# %%
import pandas as pd
import numpy as np

# Считываем данные
n = ['id', 'date', 'name', 'text', 'typr', 'rep', 'rtw', 'faw', 'stcount', 'foll', 'frien', 'listcount']
data_positive = pd.read_csv('data/positive.csv', sep=';', error_bad_lines=False, names=n, usecols=['text'])
data_negative = pd.read_csv('data/negative.csv', sep=';', error_bad_lines=False, names=n, usecols=['text'])

# Формируем сбалансированный датасет
sample_size = min(data_positive.shape[0], data_negative.shape[0])
raw_data = np.concatenate((data_positive['text'].values[:sample_size],
                           data_negative['text'].values[:sample_size]), axis=0)
labels = [1] * sample_size + [0] * sample_size

# %% [markdown]
# Перед началом обучения тексты прошли процедуру предварительной обработки:
#
# - приведение к нижнему регистру;
# - замена «ё» на «е»;
# - замена ссылок на токен «URL»;
# - замена упоминания пользователя на токен «USER»;
# - удаление знаков пунктуации.

# %%
import re

def preprocess_text(text):
    text = text.lower().replace("ё", "е")
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', text)
    text = re.sub('@[^\s]+', 'USER', text)
    text = re.sub('[^a-zA-Zа-яА-Я1-9]+', ' ', text)
    text = re.sub(' +', ' ', text)
    return text.strip()


data = [preprocess_text(t) for t in raw_data]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=1)

# %% [markdown]
# #### Векторное отображение слов

# %% [markdown]
# Входными данными сверточной нейронной сети является матрица с фиксированной высотой n, где каждая строка представляет собой векторное отображение слова в признаковое пространство размерности k.
#
# Для формирования embedding-слоя нейронной сети используем утилиту дистрибутивной семантики Word2Vec, предназначенную для отображения семантического значения слов в векторное пространство.
#
# Word2Vec находит взаимосвязи между словами согласно предположению, что в похожих контекстах встречаются семантически близкие слова. Подробнее о Word2Vec можно прочитать в оригинальной статье, а также тут и тут. Поскольку твитам характерна авторская пунктуация и эмотиконы, определение границ предложений становится достаточно трудоемкой задачей.

# %%
import sqlite3

# Открываем SQLite базу данных
conn = sqlite3.connect('mysqlite3.db')
c = conn.cursor()

# %%
with open('data/tweets.txt', 'w', encoding='utf-8') as f:
    # Считываем тексты твитов 
    for row in c.execute('SELECT ttext FROM sentiment'):
        if row[0]:
            tweet = preprocess_text(row[0])
            # Записываем предобработанные твиты в файл
            print(tweet, file=f)

# %% [markdown]
# Далее с помощью библиотеки Gensim обучаем Word2Vec-модель со следующими параметрами:
#
# - size = 200 — размерность признакового пространства;
# - window = 5 — количество слов из контекста, которое анализирует алгоритм;
# - min_count = 3 — слово должно встречаться минимум три раза, чтобы модель его учитывала.

# %%
import logging
import multiprocessing
import gensim
from gensim.models import Word2Vec

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Считываем файл с предобработанными твитами
data = gensim.models.word2vec.LineSentence('data/tweets.txt')
# Обучаем модель 
model = Word2Vec(data, size=200, window=5, min_count=3, workers=multiprocessing.cpu_count())
# Out:
# 2019-08-14 07:13:33,867 : INFO : collecting all words and their counts
# 2019-08-14 07:13:33,870 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-08-14 07:13:33,954 : INFO : PROGRESS: at sentence #10000, processed 98345 words, keeping 24248 word types
# 2019-08-14 07:13:34,026 : INFO : PROGRESS: at sentence #20000, processed 194782 words, keeping 38847 word types
# 2019-08-14 07:13:34,098 : INFO : PROGRESS: at sentence #30000, processed 290743 words, keeping 50531 word types
# 2019-08-14 07:13:34,167 : INFO : PROGRESS: at sentence #40000, processed 386269 words, keeping 60653 word types
# 2019-08-14 07:13:34,231 : INFO : PROGRESS: at sentence #50000, processed 482755 words, keeping 69689 word types
# 2019-08-14 07:13:34,305 : INFO : PROGRESS: at sentence #60000, processed 578104 words, keeping 78235 word types
# 2019-08-14 07:13:34,375 : INFO : PROGRESS: at sentence #70000, processed 672686 words, keeping 85840 word types
# 2019-08-14 07:13:34,474 : INFO : PROGRESS: at sentence #80000, processed 766898 words, keeping 93042 word types
# 2019-08-14 07:13:34,548 : INFO : PROGRESS: at sentence #90000, processed 862949 words, keeping 99911 word types
# 2019-08-14 07:13:34,613 : INFO : PROGRESS: at sentence #100000, processed 960583 words, keeping 106646 word types
# 2019-08-14 07:13:34,690 : INFO : PROGRESS: at sentence #110000, processed 1057125 words, keeping 112922 word types
# 2019-08-14 07:13:34,763 : INFO : PROGRESS: at sentence #120000, processed 1153510 words, keeping 119159 word types
# 2019-08-14 07:13:34,848 : INFO : PROGRESS: at sentence #130000, processed 1251620 words, keeping 125604 word types
# 2019-08-14 07:13:34,920 : INFO : PROGRESS: at sentence #140000, processed 1350354 words, keeping 131435 word types
# 2019-08-14 07:13:34,993 : INFO : PROGRESS: at sentence #150000, processed 1449915 words, keeping 137088 word types
# 2019-08-14 07:13:35,064 : INFO : PROGRESS: at sentence #160000, processed 1549055 words, keeping 142595 word types
# 2019-08-14 07:13:35,143 : INFO : PROGRESS: at sentence #170000, processed 1648709 words, keeping 147698 word types
# 2019-08-14 07:13:35,216 : INFO : PROGRESS: at sentence #180000, processed 1749773 words, keeping 152870 word types
# 2019-08-14 07:13:35,289 : INFO : PROGRESS: at sentence #190000, processed 1844177 words, keeping 157863 word types
# 2019-08-14 07:13:35,358 : INFO : PROGRESS: at sentence #200000, processed 1932498 words, keeping 162398 word types
# 2019-08-14 07:13:35,448 : INFO : PROGRESS: at sentence #210000, processed 2021676 words, keeping 166612 word types
# 2019-08-14 07:13:35,514 : INFO : PROGRESS: at sentence #220000, processed 2111543 words, keeping 170883 word types
# 2019-08-14 07:13:35,601 : INFO : PROGRESS: at sentence #230000, processed 2201518 words, keeping 175087 word types
# 2019-08-14 07:13:35,676 : INFO : PROGRESS: at sentence #240000, processed 2291279 words, keeping 179185 word types
# 2019-08-14 07:13:35,748 : INFO : PROGRESS: at sentence #250000, processed 2379759 words, keeping 183130 word types
# 2019-08-14 07:13:35,831 : INFO : PROGRESS: at sentence #260000, processed 2471185 words, keeping 186995 word types
# 2019-08-14 07:13:35,903 : INFO : PROGRESS: at sentence #270000, processed 2563446 words, keeping 191045 word types
# 2019-08-14 07:13:35,972 : INFO : PROGRESS: at sentence #280000, processed 2655825 words, keeping 195098 word types
# 2019-08-14 07:13:36,040 : INFO : PROGRESS: at sentence #290000, processed 2748551 words, keeping 199274 word types
# 2019-08-14 07:13:36,114 : INFO : PROGRESS: at sentence #300000, processed 2841352 words, keeping 203215 word types
# 2019-08-14 07:13:36,184 : INFO : PROGRESS: at sentence #310000, processed 2934107 words, keeping 207001 word types
# 2019-08-14 07:13:36,270 : INFO : PROGRESS: at sentence #320000, processed 3026466 words, keeping 210658 word types
# 2019-08-14 07:13:36,341 : INFO : PROGRESS: at sentence #330000, processed 3119532 words, keeping 214271 word types
# 2019-08-14 07:13:36,411 : INFO : PROGRESS: at sentence #340000, processed 3213103 words, keeping 217988 word types
# 2019-08-14 07:13:36,490 : INFO : PROGRESS: at sentence #350000, processed 3307179 words, keeping 221624 word types
# 2019-08-14 07:13:36,561 : INFO : PROGRESS: at sentence #360000, processed 3400968 words, keeping 225040 word types
# 2019-08-14 07:13:36,633 : INFO : PROGRESS: at sentence #370000, processed 3495005 words, keeping 228335 word types
# 2019-08-14 07:13:36,698 : INFO : PROGRESS: at sentence #380000, processed 3590438 words, keeping 231791 word types
# 2019-08-14 07:13:36,776 : INFO : PROGRESS: at sentence #390000, processed 3684054 words, keeping 235043 word types
# 2019-08-14 07:13:36,849 : INFO : PROGRESS: at sentence #400000, processed 3780186 words, keeping 238354 word types
# 2019-08-14 07:13:36,932 : INFO : PROGRESS: at sentence #410000, processed 3876302 words, keeping 241480 word types
# 2019-08-14 07:13:36,996 : INFO : PROGRESS: at sentence #420000, processed 3971841 words, keeping 244717 word types
# 2019-08-14 07:13:37,074 : INFO : PROGRESS: at sentence #430000, processed 4067909 words, keeping 247850 word types
# 2019-08-14 07:13:37,146 : INFO : PROGRESS: at sentence #440000, processed 4162950 words, keeping 250983 word types
# 2019-08-14 07:13:37,217 : INFO : PROGRESS: at sentence #450000, processed 4259648 words, keeping 253960 word types
# 2019-08-14 07:13:37,288 : INFO : PROGRESS: at sentence #460000, processed 4356352 words, keeping 256913 word types
# 2019-08-14 07:13:37,360 : INFO : PROGRESS: at sentence #470000, processed 4451580 words, keeping 259937 word types
# 2019-08-14 07:13:37,430 : INFO : PROGRESS: at sentence #480000, processed 4547378 words, keeping 262978 word types
# 2019-08-14 07:13:37,500 : INFO : PROGRESS: at sentence #490000, processed 4643338 words, keeping 266003 word types
# 2019-08-14 07:13:37,584 : INFO : PROGRESS: at sentence #500000, processed 4740367 words, keeping 268846 word types
# 2019-08-14 07:13:37,668 : INFO : PROGRESS: at sentence #510000, processed 4836976 words, keeping 271791 word types
# 2019-08-14 07:13:37,742 : INFO : PROGRESS: at sentence #520000, processed 4934129 words, keeping 274941 word types
# 2019-08-14 07:13:37,814 : INFO : PROGRESS: at sentence #530000, processed 5030563 words, keeping 278001 word types
# 2019-08-14 07:13:37,893 : INFO : PROGRESS: at sentence #540000, processed 5128910 words, keeping 281133 word types
# 2019-08-14 07:13:37,971 : INFO : PROGRESS: at sentence #550000, processed 5225597 words, keeping 284115 word types
# 2019-08-14 07:13:38,040 : INFO : PROGRESS: at sentence #560000, processed 5320399 words, keeping 287363 word types
# 2019-08-14 07:13:38,113 : INFO : PROGRESS: at sentence #570000, processed 5415927 words, keeping 290230 word types
# 2019-08-14 07:13:38,185 : INFO : PROGRESS: at sentence #580000, processed 5509600 words, keeping 293091 word types
# 2019-08-14 07:13:38,257 : INFO : PROGRESS: at sentence #590000, processed 5607180 words, keeping 295896 word types
# 2019-08-14 07:13:38,323 : INFO : PROGRESS: at sentence #600000, processed 5704634 words, keeping 298654 word types
# 2019-08-14 07:13:38,408 : INFO : PROGRESS: at sentence #610000, processed 5800889 words, keeping 301554 word types
# 2019-08-14 07:13:38,472 : INFO : PROGRESS: at sentence #620000, processed 5892305 words, keeping 303984 word types
# 2019-08-14 07:13:38,545 : INFO : PROGRESS: at sentence #630000, processed 5986123 words, keeping 306511 word types
# 2019-08-14 07:13:38,612 : INFO : PROGRESS: at sentence #640000, processed 6081863 words, keeping 309168 word types
# 2019-08-14 07:13:38,691 : INFO : PROGRESS: at sentence #650000, processed 6180112 words, keeping 311895 word types
# 2019-08-14 07:13:38,763 : INFO : PROGRESS: at sentence #660000, processed 6278093 words, keeping 314321 word types
# 2019-08-14 07:13:38,830 : INFO : PROGRESS: at sentence #670000, processed 6374195 words, keeping 316642 word types
# 2019-08-14 07:13:38,904 : INFO : PROGRESS: at sentence #680000, processed 6469612 words, keeping 319114 word types
# 2019-08-14 07:13:38,972 : INFO : PROGRESS: at sentence #690000, processed 6565473 words, keeping 321706 word types
# 2019-08-14 07:13:39,047 : INFO : PROGRESS: at sentence #700000, processed 6662804 words, keeping 324199 word types
# 2019-08-14 07:13:39,113 : INFO : PROGRESS: at sentence #710000, processed 6760355 words, keeping 326879 word types
# 2019-08-14 07:13:39,197 : INFO : PROGRESS: at sentence #720000, processed 6856226 words, keeping 329362 word types
# 2019-08-14 07:13:39,261 : INFO : PROGRESS: at sentence #730000, processed 6953689 words, keeping 331913 word types
# 2019-08-14 07:13:39,335 : INFO : PROGRESS: at sentence #740000, processed 7054203 words, keeping 334539 word types
# 2019-08-14 07:13:39,403 : INFO : PROGRESS: at sentence #750000, processed 7153523 words, keeping 336844 word types
# 2019-08-14 07:13:39,483 : INFO : PROGRESS: at sentence #760000, processed 7253230 words, keeping 339124 word types
# 2019-08-14 07:13:39,552 : INFO : PROGRESS: at sentence #770000, processed 7352424 words, keeping 341418 word types
# 2019-08-14 07:13:39,623 : INFO : PROGRESS: at sentence #780000, processed 7450987 words, keeping 343877 word types
# 2019-08-14 07:13:39,699 : INFO : PROGRESS: at sentence #790000, processed 7545233 words, keeping 346595 word types
# 2019-08-14 07:13:39,763 : INFO : PROGRESS: at sentence #800000, processed 7638657 words, keeping 349110 word types
# 2019-08-14 07:13:39,865 : INFO : PROGRESS: at sentence #810000, processed 7732384 words, keeping 351571 word types
# 2019-08-14 07:13:39,932 : INFO : PROGRESS: at sentence #820000, processed 7825587 words, keeping 354161 word types
# 2019-08-14 07:13:40,014 : INFO : PROGRESS: at sentence #830000, processed 7917707 words, keeping 356535 word types
# 2019-08-14 07:13:40,081 : INFO : PROGRESS: at sentence #840000, processed 8009850 words, keeping 358905 word types
# 2019-08-14 07:13:40,153 : INFO : PROGRESS: at sentence #850000, processed 8102269 words, keeping 361280 word types
# 2019-08-14 07:13:40,228 : INFO : PROGRESS: at sentence #860000, processed 8193920 words, keeping 363700 word types
# 2019-08-14 07:13:40,300 : INFO : PROGRESS: at sentence #870000, processed 8286317 words, keeping 365872 word types
# 2019-08-14 07:13:40,369 : INFO : PROGRESS: at sentence #880000, processed 8380228 words, keeping 368083 word types
# 2019-08-14 07:13:40,438 : INFO : PROGRESS: at sentence #890000, processed 8471931 words, keeping 370293 word types
# 2019-08-14 07:13:40,516 : INFO : PROGRESS: at sentence #900000, processed 8562960 words, keeping 372426 word types
# 2019-08-14 07:13:40,579 : INFO : PROGRESS: at sentence #910000, processed 8653461 words, keeping 374497 word types
# 2019-08-14 07:13:40,661 : INFO : PROGRESS: at sentence #920000, processed 8744068 words, keeping 376630 word types
# 2019-08-14 07:13:40,728 : INFO : PROGRESS: at sentence #930000, processed 8834622 words, keeping 378829 word types
# 2019-08-14 07:13:40,809 : INFO : PROGRESS: at sentence #940000, processed 8927062 words, keeping 381155 word types
# 2019-08-14 07:13:40,871 : INFO : PROGRESS: at sentence #950000, processed 9017861 words, keeping 383354 word types
# 2019-08-14 07:13:40,952 : INFO : PROGRESS: at sentence #960000, processed 9107195 words, keeping 385617 word types
# 2019-08-14 07:13:41,016 : INFO : PROGRESS: at sentence #970000, processed 9200576 words, keeping 387843 word types
# 2019-08-14 07:13:41,089 : INFO : PROGRESS: at sentence #980000, processed 9296062 words, keeping 390113 word types
# 2019-08-14 07:13:41,155 : INFO : PROGRESS: at sentence #990000, processed 9394348 words, keeping 392533 word types
# 2019-08-14 07:13:41,239 : INFO : PROGRESS: at sentence #1000000, processed 9490953 words, keeping 394941 word types
# 2019-08-14 07:13:41,312 : INFO : PROGRESS: at sentence #1010000, processed 9588800 words, keeping 397551 word types
# 2019-08-14 07:13:41,396 : INFO : PROGRESS: at sentence #1020000, processed 9687758 words, keeping 400171 word types
# 2019-08-14 07:13:41,467 : INFO : PROGRESS: at sentence #1030000, processed 9786911 words, keeping 402713 word types
# 2019-08-14 07:13:41,553 : INFO : PROGRESS: at sentence #1040000, processed 9887663 words, keeping 405271 word types
# 2019-08-14 07:13:41,624 : INFO : PROGRESS: at sentence #1050000, processed 9985939 words, keeping 407851 word types
# 2019-08-14 07:13:41,707 : INFO : PROGRESS: at sentence #1060000, processed 10085947 words, keeping 410339 word types
# 2019-08-14 07:13:41,775 : INFO : PROGRESS: at sentence #1070000, processed 10183614 words, keeping 412892 word types
# 2019-08-14 07:13:41,852 : INFO : PROGRESS: at sentence #1080000, processed 10282420 words, keeping 415318 word types
# 2019-08-14 07:13:41,928 : INFO : PROGRESS: at sentence #1090000, processed 10380423 words, keeping 417742 word types
# 2019-08-14 07:13:41,995 : INFO : PROGRESS: at sentence #1100000, processed 10477454 words, keeping 420171 word types
# 2019-08-14 07:13:42,078 : INFO : PROGRESS: at sentence #1110000, processed 10572868 words, keeping 422561 word types
# 2019-08-14 07:13:42,148 : INFO : PROGRESS: at sentence #1120000, processed 10670717 words, keeping 424950 word types
# 2019-08-14 07:13:42,226 : INFO : PROGRESS: at sentence #1130000, processed 10767675 words, keeping 427418 word types
# 2019-08-14 07:13:42,296 : INFO : PROGRESS: at sentence #1140000, processed 10865524 words, keeping 429848 word types
# 2019-08-14 07:13:42,368 : INFO : PROGRESS: at sentence #1150000, processed 10963566 words, keeping 432161 word types
# 2019-08-14 07:13:42,438 : INFO : PROGRESS: at sentence #1160000, processed 11061984 words, keeping 434399 word types
# 2019-08-14 07:13:42,513 : INFO : PROGRESS: at sentence #1170000, processed 11159158 words, keeping 436619 word types
# 2019-08-14 07:13:42,579 : INFO : PROGRESS: at sentence #1180000, processed 11257018 words, keeping 438817 word types
# 2019-08-14 07:13:42,665 : INFO : PROGRESS: at sentence #1190000, processed 11354273 words, keeping 440986 word types
# 2019-08-14 07:13:42,734 : INFO : PROGRESS: at sentence #1200000, processed 11451632 words, keeping 443185 word types
# 2019-08-14 07:13:42,811 : INFO : PROGRESS: at sentence #1210000, processed 11549818 words, keeping 445570 word types
# 2019-08-14 07:13:42,882 : INFO : PROGRESS: at sentence #1220000, processed 11648893 words, keeping 447835 word types
# 2019-08-14 07:13:42,958 : INFO : PROGRESS: at sentence #1230000, processed 11745879 words, keeping 450008 word types
# 2019-08-14 07:13:43,023 : INFO : PROGRESS: at sentence #1240000, processed 11844698 words, keeping 452272 word types
# 2019-08-14 07:13:43,109 : INFO : PROGRESS: at sentence #1250000, processed 11942435 words, keeping 454521 word types
# 2019-08-14 07:13:43,174 : INFO : PROGRESS: at sentence #1260000, processed 12040135 words, keeping 456742 word types
# 2019-08-14 07:13:43,259 : INFO : PROGRESS: at sentence #1270000, processed 12136313 words, keeping 459013 word types
# 2019-08-14 07:13:43,328 : INFO : PROGRESS: at sentence #1280000, processed 12233843 words, keeping 461227 word types
# 2019-08-14 07:13:43,414 : INFO : PROGRESS: at sentence #1290000, processed 12330330 words, keeping 463518 word types
# 2019-08-14 07:13:43,485 : INFO : PROGRESS: at sentence #1300000, processed 12428330 words, keeping 465594 word types
# 2019-08-14 07:13:43,554 : INFO : PROGRESS: at sentence #1310000, processed 12523484 words, keeping 467727 word types
# 2019-08-14 07:13:43,630 : INFO : PROGRESS: at sentence #1320000, processed 12621299 words, keeping 469832 word types
# 2019-08-14 07:13:43,700 : INFO : PROGRESS: at sentence #1330000, processed 12719227 words, keeping 472002 word types
# 2019-08-14 07:13:43,786 : INFO : PROGRESS: at sentence #1340000, processed 12816309 words, keeping 474043 word types
# 2019-08-14 07:13:43,869 : INFO : PROGRESS: at sentence #1350000, processed 12913320 words, keeping 476070 word types
# 2019-08-14 07:13:43,966 : INFO : PROGRESS: at sentence #1360000, processed 13010564 words, keeping 478149 word types
# 2019-08-14 07:13:44,045 : INFO : PROGRESS: at sentence #1370000, processed 13107962 words, keeping 480417 word types
# 2019-08-14 07:13:44,119 : INFO : PROGRESS: at sentence #1380000, processed 13206006 words, keeping 482730 word types
# 2019-08-14 07:13:44,187 : INFO : PROGRESS: at sentence #1390000, processed 13303224 words, keeping 485076 word types
# 2019-08-14 07:13:44,272 : INFO : PROGRESS: at sentence #1400000, processed 13400877 words, keeping 487417 word types
# 2019-08-14 07:13:44,367 : INFO : PROGRESS: at sentence #1410000, processed 13500006 words, keeping 489589 word types
# 2019-08-14 07:13:44,460 : INFO : PROGRESS: at sentence #1420000, processed 13599684 words, keeping 491877 word types
# 2019-08-14 07:13:44,536 : INFO : PROGRESS: at sentence #1430000, processed 13698594 words, keeping 494012 word types
# 2019-08-14 07:13:44,613 : INFO : PROGRESS: at sentence #1440000, processed 13799436 words, keeping 496301 word types
# 2019-08-14 07:13:44,686 : INFO : PROGRESS: at sentence #1450000, processed 13898908 words, keeping 498556 word types
# 2019-08-14 07:13:44,764 : INFO : PROGRESS: at sentence #1460000, processed 13996483 words, keeping 500687 word types
# 2019-08-14 07:13:44,836 : INFO : PROGRESS: at sentence #1470000, processed 14094360 words, keeping 502819 word types
# 2019-08-14 07:13:44,908 : INFO : PROGRESS: at sentence #1480000, processed 14192679 words, keeping 504855 word types
# 2019-08-14 07:13:45,001 : INFO : PROGRESS: at sentence #1490000, processed 14291910 words, keeping 507157 word types
# 2019-08-14 07:13:45,089 : INFO : PROGRESS: at sentence #1500000, processed 14391159 words, keeping 509297 word types
# 2019-08-14 07:13:45,160 : INFO : PROGRESS: at sentence #1510000, processed 14490235 words, keeping 511413 word types
# 2019-08-14 07:13:45,246 : INFO : PROGRESS: at sentence #1520000, processed 14588798 words, keeping 513481 word types
# 2019-08-14 07:13:45,320 : INFO : PROGRESS: at sentence #1530000, processed 14687570 words, keeping 515509 word types
# 2019-08-14 07:13:45,393 : INFO : PROGRESS: at sentence #1540000, processed 14786588 words, keeping 517588 word types
# 2019-08-14 07:13:45,462 : INFO : PROGRESS: at sentence #1550000, processed 14885527 words, keeping 519738 word types
# 2019-08-14 07:13:45,533 : INFO : PROGRESS: at sentence #1560000, processed 14980014 words, keeping 521715 word types
# 2019-08-14 07:13:45,609 : INFO : PROGRESS: at sentence #1570000, processed 15073577 words, keeping 523638 word types
# 2019-08-14 07:13:45,672 : INFO : PROGRESS: at sentence #1580000, processed 15166370 words, keeping 525501 word types
# 2019-08-14 07:13:45,753 : INFO : PROGRESS: at sentence #1590000, processed 15259922 words, keeping 527331 word types
# 2019-08-14 07:13:45,821 : INFO : PROGRESS: at sentence #1600000, processed 15353121 words, keeping 529110 word types
# 2019-08-14 07:13:45,903 : INFO : PROGRESS: at sentence #1610000, processed 15447227 words, keeping 530823 word types
# 2019-08-14 07:13:45,979 : INFO : PROGRESS: at sentence #1620000, processed 15543401 words, keeping 532767 word types
# 2019-08-14 07:13:46,069 : INFO : PROGRESS: at sentence #1630000, processed 15640563 words, keeping 534767 word types
# 2019-08-14 07:13:46,136 : INFO : PROGRESS: at sentence #1640000, processed 15739521 words, keeping 536806 word types
# 2019-08-14 07:13:46,223 : INFO : PROGRESS: at sentence #1650000, processed 15837020 words, keeping 538696 word types
# 2019-08-14 07:13:46,290 : INFO : PROGRESS: at sentence #1660000, processed 15934712 words, keeping 540666 word types
# 2019-08-14 07:13:46,375 : INFO : PROGRESS: at sentence #1670000, processed 16032905 words, keeping 542562 word types
# 2019-08-14 07:13:46,446 : INFO : PROGRESS: at sentence #1680000, processed 16131539 words, keeping 544612 word types
# 2019-08-14 07:13:46,530 : INFO : PROGRESS: at sentence #1690000, processed 16232283 words, keeping 546805 word types
# 2019-08-14 07:13:46,604 : INFO : PROGRESS: at sentence #1700000, processed 16332680 words, keeping 548835 word types
# 2019-08-14 07:13:46,678 : INFO : PROGRESS: at sentence #1710000, processed 16431288 words, keeping 551009 word types
# 2019-08-14 07:13:46,751 : INFO : PROGRESS: at sentence #1720000, processed 16530520 words, keeping 553042 word types
# 2019-08-14 07:13:46,835 : INFO : PROGRESS: at sentence #1730000, processed 16628262 words, keeping 555013 word types
# 2019-08-14 07:13:46,910 : INFO : PROGRESS: at sentence #1740000, processed 16726922 words, keeping 556934 word types
# 2019-08-14 07:13:46,980 : INFO : PROGRESS: at sentence #1750000, processed 16823199 words, keeping 558762 word types
# 2019-08-14 07:13:47,055 : INFO : PROGRESS: at sentence #1760000, processed 16920421 words, keeping 560586 word types
# 2019-08-14 07:13:47,131 : INFO : PROGRESS: at sentence #1770000, processed 17018366 words, keeping 562488 word types
# 2019-08-14 07:13:47,208 : INFO : PROGRESS: at sentence #1780000, processed 17115635 words, keeping 564286 word types
# 2019-08-14 07:13:47,278 : INFO : PROGRESS: at sentence #1790000, processed 17213201 words, keeping 566160 word types
# 2019-08-14 07:13:47,356 : INFO : PROGRESS: at sentence #1800000, processed 17310998 words, keeping 568084 word types
# 2019-08-14 07:13:47,431 : INFO : PROGRESS: at sentence #1810000, processed 17410050 words, keeping 569933 word types
# 2019-08-14 07:13:47,502 : INFO : PROGRESS: at sentence #1820000, processed 17508904 words, keeping 571716 word types
# 2019-08-14 07:13:47,573 : INFO : PROGRESS: at sentence #1830000, processed 17607497 words, keeping 573556 word types
# 2019-08-14 07:13:47,649 : INFO : PROGRESS: at sentence #1840000, processed 17705727 words, keeping 575314 word types
# 2019-08-14 07:13:47,718 : INFO : PROGRESS: at sentence #1850000, processed 17803993 words, keeping 577093 word types
# 2019-08-14 07:13:47,801 : INFO : PROGRESS: at sentence #1860000, processed 17902273 words, keeping 578794 word types
# 2019-08-14 07:13:47,869 : INFO : PROGRESS: at sentence #1870000, processed 18000386 words, keeping 580585 word types
# 2019-08-14 07:13:47,957 : INFO : PROGRESS: at sentence #1880000, processed 18097331 words, keeping 582338 word types
# 2019-08-14 07:13:48,027 : INFO : PROGRESS: at sentence #1890000, processed 18196157 words, keeping 584019 word types
# 2019-08-14 07:13:48,108 : INFO : PROGRESS: at sentence #1900000, processed 18295519 words, keeping 585764 word types
# 2019-08-14 07:13:48,177 : INFO : PROGRESS: at sentence #1910000, processed 18392882 words, keeping 587546 word types
# 2019-08-14 07:13:48,261 : INFO : PROGRESS: at sentence #1920000, processed 18489752 words, keeping 589208 word types
# 2019-08-14 07:13:48,333 : INFO : PROGRESS: at sentence #1930000, processed 18588640 words, keeping 590960 word types
# 2019-08-14 07:13:48,417 : INFO : PROGRESS: at sentence #1940000, processed 18685858 words, keeping 592586 word types
# 2019-08-14 07:13:48,491 : INFO : PROGRESS: at sentence #1950000, processed 18782923 words, keeping 594123 word types
# 2019-08-14 07:13:48,562 : INFO : PROGRESS: at sentence #1960000, processed 18880485 words, keeping 595811 word types
# 2019-08-14 07:13:48,640 : INFO : PROGRESS: at sentence #1970000, processed 18978117 words, keeping 597512 word types
# 2019-08-14 07:13:48,709 : INFO : PROGRESS: at sentence #1980000, processed 19076220 words, keeping 599221 word types
# 2019-08-14 07:13:48,789 : INFO : PROGRESS: at sentence #1990000, processed 19174023 words, keeping 600838 word types
# 2019-08-14 07:13:48,861 : INFO : PROGRESS: at sentence #2000000, processed 19271517 words, keeping 602607 word types
# 2019-08-14 07:13:48,944 : INFO : PROGRESS: at sentence #2010000, processed 19371338 words, keeping 604254 word types
# 2019-08-14 07:13:49,023 : INFO : PROGRESS: at sentence #2020000, processed 19468491 words, keeping 605894 word types
# 2019-08-14 07:13:49,106 : INFO : PROGRESS: at sentence #2030000, processed 19564336 words, keeping 607683 word types
# 2019-08-14 07:13:49,177 : INFO : PROGRESS: at sentence #2040000, processed 19657308 words, keeping 609295 word types
# 2019-08-14 07:13:49,259 : INFO : PROGRESS: at sentence #2050000, processed 19750963 words, keeping 610964 word types
# 2019-08-14 07:13:49,330 : INFO : PROGRESS: at sentence #2060000, processed 19847316 words, keeping 612621 word types
# 2019-08-14 07:13:49,413 : INFO : PROGRESS: at sentence #2070000, processed 19943485 words, keeping 614244 word types
# 2019-08-14 07:13:49,484 : INFO : PROGRESS: at sentence #2080000, processed 20039302 words, keeping 615973 word types
# 2019-08-14 07:13:49,566 : INFO : PROGRESS: at sentence #2090000, processed 20135275 words, keeping 617689 word types
# 2019-08-14 07:13:49,637 : INFO : PROGRESS: at sentence #2100000, processed 20231222 words, keeping 619243 word types
# 2019-08-14 07:13:49,722 : INFO : PROGRESS: at sentence #2110000, processed 20327331 words, keeping 620815 word types
# 2019-08-14 07:13:49,794 : INFO : PROGRESS: at sentence #2120000, processed 20423744 words, keeping 622484 word types
# 2019-08-14 07:13:49,872 : INFO : PROGRESS: at sentence #2130000, processed 20522860 words, keeping 624259 word types
# 2019-08-14 07:13:49,945 : INFO : PROGRESS: at sentence #2140000, processed 20623466 words, keeping 625917 word types
# 2019-08-14 07:13:50,025 : INFO : PROGRESS: at sentence #2150000, processed 20722248 words, keeping 627462 word types
# 2019-08-14 07:13:50,094 : INFO : PROGRESS: at sentence #2160000, processed 20819863 words, keeping 629122 word types
# 2019-08-14 07:13:50,180 : INFO : PROGRESS: at sentence #2170000, processed 20917554 words, keeping 630708 word types
# 2019-08-14 07:13:50,251 : INFO : PROGRESS: at sentence #2180000, processed 21015641 words, keeping 632393 word types
# 2019-08-14 07:13:50,334 : INFO : PROGRESS: at sentence #2190000, processed 21113827 words, keeping 634124 word types
# 2019-08-14 07:13:50,403 : INFO : PROGRESS: at sentence #2200000, processed 21212464 words, keeping 635844 word types
# 2019-08-14 07:13:50,489 : INFO : PROGRESS: at sentence #2210000, processed 21310897 words, keeping 637585 word types
# 2019-08-14 07:13:50,569 : INFO : PROGRESS: at sentence #2220000, processed 21412982 words, keeping 639328 word types
# 2019-08-14 07:13:50,660 : INFO : PROGRESS: at sentence #2230000, processed 21513363 words, keeping 641070 word types
# 2019-08-14 07:13:50,732 : INFO : PROGRESS: at sentence #2240000, processed 21613121 words, keeping 642907 word types
# 2019-08-14 07:13:50,813 : INFO : PROGRESS: at sentence #2250000, processed 21712137 words, keeping 644586 word types
# 2019-08-14 07:13:50,886 : INFO : PROGRESS: at sentence #2260000, processed 21811870 words, keeping 646356 word types
# 2019-08-14 07:13:50,957 : INFO : PROGRESS: at sentence #2270000, processed 21910480 words, keeping 648078 word types
# 2019-08-14 07:13:51,035 : INFO : PROGRESS: at sentence #2280000, processed 22008331 words, keeping 649777 word types
# 2019-08-14 07:13:51,101 : INFO : PROGRESS: at sentence #2290000, processed 22106680 words, keeping 651490 word types
# 2019-08-14 07:13:51,185 : INFO : PROGRESS: at sentence #2300000, processed 22204894 words, keeping 653193 word types
# 2019-08-14 07:13:51,251 : INFO : PROGRESS: at sentence #2310000, processed 22302447 words, keeping 654826 word types
# 2019-08-14 07:13:51,335 : INFO : PROGRESS: at sentence #2320000, processed 22400635 words, keeping 656475 word types
# 2019-08-14 07:13:51,401 : INFO : PROGRESS: at sentence #2330000, processed 22497984 words, keeping 658073 word types
# 2019-08-14 07:13:51,486 : INFO : PROGRESS: at sentence #2340000, processed 22594490 words, keeping 659685 word types
# 2019-08-14 07:13:51,555 : INFO : PROGRESS: at sentence #2350000, processed 22688509 words, keeping 661297 word types
# 2019-08-14 07:13:51,631 : INFO : PROGRESS: at sentence #2360000, processed 22784399 words, keeping 662831 word types
# 2019-08-14 07:13:51,698 : INFO : PROGRESS: at sentence #2370000, processed 22881155 words, keeping 664432 word types
# 2019-08-14 07:13:51,785 : INFO : PROGRESS: at sentence #2380000, processed 22977722 words, keeping 666014 word types
# 2019-08-14 07:13:51,855 : INFO : PROGRESS: at sentence #2390000, processed 23075356 words, keeping 667565 word types
# 2019-08-14 07:13:51,938 : INFO : PROGRESS: at sentence #2400000, processed 23173245 words, keeping 669115 word types
# 2019-08-14 07:13:52,005 : INFO : PROGRESS: at sentence #2410000, processed 23270648 words, keeping 670753 word types
# 2019-08-14 07:13:52,093 : INFO : PROGRESS: at sentence #2420000, processed 23369206 words, keeping 672506 word types
# 2019-08-14 07:13:52,164 : INFO : PROGRESS: at sentence #2430000, processed 23468037 words, keeping 674254 word types
# 2019-08-14 07:13:52,239 : INFO : PROGRESS: at sentence #2440000, processed 23565713 words, keeping 676004 word types
# 2019-08-14 07:13:52,312 : INFO : PROGRESS: at sentence #2450000, processed 23664128 words, keeping 677700 word types
# 2019-08-14 07:13:52,389 : INFO : PROGRESS: at sentence #2460000, processed 23761281 words, keeping 679459 word types
# 2019-08-14 07:13:52,461 : INFO : PROGRESS: at sentence #2470000, processed 23858907 words, keeping 681176 word types
# 2019-08-14 07:13:52,530 : INFO : PROGRESS: at sentence #2480000, processed 23958086 words, keeping 682916 word types
# 2019-08-14 07:13:52,611 : INFO : PROGRESS: at sentence #2490000, processed 24057289 words, keeping 684599 word types
# 2019-08-14 07:13:52,680 : INFO : PROGRESS: at sentence #2500000, processed 24158346 words, keeping 686170 word types
# 2019-08-14 07:13:52,761 : INFO : PROGRESS: at sentence #2510000, processed 24258377 words, keeping 687912 word types
# 2019-08-14 07:13:52,834 : INFO : PROGRESS: at sentence #2520000, processed 24358807 words, keeping 689628 word types
# 2019-08-14 07:13:52,912 : INFO : PROGRESS: at sentence #2530000, processed 24458330 words, keeping 691312 word types
# 2019-08-14 07:13:52,983 : INFO : PROGRESS: at sentence #2540000, processed 24557381 words, keeping 692961 word types
# 2019-08-14 07:13:53,060 : INFO : PROGRESS: at sentence #2550000, processed 24655064 words, keeping 694546 word types
# 2019-08-14 07:13:53,128 : INFO : PROGRESS: at sentence #2560000, processed 24752420 words, keeping 696249 word types
# 2019-08-14 07:13:53,212 : INFO : PROGRESS: at sentence #2570000, processed 24851338 words, keeping 697922 word types
# 2019-08-14 07:13:53,338 : INFO : PROGRESS: at sentence #2580000, processed 24950414 words, keeping 699507 word types
# 2019-08-14 07:13:53,421 : INFO : PROGRESS: at sentence #2590000, processed 25049019 words, keeping 701070 word types
# 2019-08-14 07:13:53,492 : INFO : PROGRESS: at sentence #2600000, processed 25148660 words, keeping 702779 word types
# 2019-08-14 07:13:53,573 : INFO : PROGRESS: at sentence #2610000, processed 25246945 words, keeping 704458 word types
# 2019-08-14 07:13:53,643 : INFO : PROGRESS: at sentence #2620000, processed 25342975 words, keeping 706075 word types
# 2019-08-14 07:13:53,719 : INFO : PROGRESS: at sentence #2630000, processed 25440684 words, keeping 707703 word types
# 2019-08-14 07:13:53,788 : INFO : PROGRESS: at sentence #2640000, processed 25537657 words, keeping 709327 word types
# 2019-08-14 07:13:53,872 : INFO : PROGRESS: at sentence #2650000, processed 25633878 words, keeping 710938 word types
# 2019-08-14 07:13:53,939 : INFO : PROGRESS: at sentence #2660000, processed 25729587 words, keeping 712515 word types
# 2019-08-14 07:13:54,025 : INFO : PROGRESS: at sentence #2670000, processed 25826498 words, keeping 714058 word types
# 2019-08-14 07:13:54,095 : INFO : PROGRESS: at sentence #2680000, processed 25924541 words, keeping 715593 word types
# 2019-08-14 07:13:54,176 : INFO : PROGRESS: at sentence #2690000, processed 26019934 words, keeping 717161 word types
# 2019-08-14 07:13:54,242 : INFO : PROGRESS: at sentence #2700000, processed 26114780 words, keeping 718751 word types
# 2019-08-14 07:13:54,327 : INFO : PROGRESS: at sentence #2710000, processed 26210280 words, keeping 720181 word types
# 2019-08-14 07:13:54,396 : INFO : PROGRESS: at sentence #2720000, processed 26305445 words, keeping 721705 word types
# 2019-08-14 07:13:54,469 : INFO : PROGRESS: at sentence #2730000, processed 26400698 words, keeping 723206 word types
# 2019-08-14 07:13:54,538 : INFO : PROGRESS: at sentence #2740000, processed 26494795 words, keeping 724703 word types
# 2019-08-14 07:13:54,607 : INFO : PROGRESS: at sentence #2750000, processed 26590251 words, keeping 726234 word types
# 2019-08-14 07:13:54,684 : INFO : PROGRESS: at sentence #2760000, processed 26687243 words, keeping 727671 word types
# 2019-08-14 07:13:54,751 : INFO : PROGRESS: at sentence #2770000, processed 26783366 words, keeping 729176 word types
# 2019-08-14 07:13:54,825 : INFO : PROGRESS: at sentence #2780000, processed 26880908 words, keeping 730629 word types
# 2019-08-14 07:13:54,892 : INFO : PROGRESS: at sentence #2790000, processed 26979243 words, keeping 732136 word types
# 2019-08-14 07:13:54,978 : INFO : PROGRESS: at sentence #2800000, processed 27078653 words, keeping 733686 word types
# 2019-08-14 07:13:55,051 : INFO : PROGRESS: at sentence #2810000, processed 27180555 words, keeping 735581 word types
# 2019-08-14 07:13:55,131 : INFO : PROGRESS: at sentence #2820000, processed 27286753 words, keeping 737306 word types
# 2019-08-14 07:13:55,204 : INFO : PROGRESS: at sentence #2830000, processed 27386780 words, keeping 739096 word types
# 2019-08-14 07:13:55,283 : INFO : PROGRESS: at sentence #2840000, processed 27489301 words, keeping 740788 word types
# 2019-08-14 07:13:55,355 : INFO : PROGRESS: at sentence #2850000, processed 27587700 words, keeping 742350 word types
# 2019-08-14 07:13:55,439 : INFO : PROGRESS: at sentence #2860000, processed 27686628 words, keeping 744033 word types
# 2019-08-14 07:13:55,517 : INFO : PROGRESS: at sentence #2870000, processed 27788789 words, keeping 745708 word types
# 2019-08-14 07:13:55,595 : INFO : PROGRESS: at sentence #2880000, processed 27885614 words, keeping 747258 word types
# 2019-08-14 07:13:55,660 : INFO : PROGRESS: at sentence #2890000, processed 27979645 words, keeping 748829 word types
# 2019-08-14 07:13:55,745 : INFO : PROGRESS: at sentence #2900000, processed 28075614 words, keeping 750449 word types
# 2019-08-14 07:13:55,815 : INFO : PROGRESS: at sentence #2910000, processed 28172950 words, keeping 752004 word types
# 2019-08-14 07:13:55,888 : INFO : PROGRESS: at sentence #2920000, processed 28270410 words, keeping 753472 word types
# 2019-08-14 07:13:55,959 : INFO : PROGRESS: at sentence #2930000, processed 28367928 words, keeping 754926 word types
# 2019-08-14 07:13:56,030 : INFO : PROGRESS: at sentence #2940000, processed 28464736 words, keeping 756392 word types
# 2019-08-14 07:13:56,100 : INFO : PROGRESS: at sentence #2950000, processed 28561243 words, keeping 757862 word types
# 2019-08-14 07:13:56,180 : INFO : PROGRESS: at sentence #2960000, processed 28658181 words, keeping 759297 word types
# 2019-08-14 07:13:56,255 : INFO : PROGRESS: at sentence #2970000, processed 28755549 words, keeping 760806 word types
# 2019-08-14 07:13:56,328 : INFO : PROGRESS: at sentence #2980000, processed 28851046 words, keeping 762256 word types
# 2019-08-14 07:13:56,398 : INFO : PROGRESS: at sentence #2990000, processed 28945580 words, keeping 763714 word types
# 2019-08-14 07:13:56,467 : INFO : PROGRESS: at sentence #3000000, processed 29041756 words, keeping 765260 word types
# 2019-08-14 07:13:56,538 : INFO : PROGRESS: at sentence #3010000, processed 29138912 words, keeping 766809 word types
# 2019-08-14 07:13:56,610 : INFO : PROGRESS: at sentence #3020000, processed 29236480 words, keeping 768405 word types
# 2019-08-14 07:13:56,684 : INFO : PROGRESS: at sentence #3030000, processed 29334709 words, keeping 769911 word types
# 2019-08-14 07:13:56,753 : INFO : PROGRESS: at sentence #3040000, processed 29431528 words, keeping 771378 word types
# 2019-08-14 07:13:56,824 : INFO : PROGRESS: at sentence #3050000, processed 29527222 words, keeping 772863 word types
# 2019-08-14 07:13:56,894 : INFO : PROGRESS: at sentence #3060000, processed 29623471 words, keeping 774361 word types
# 2019-08-14 07:13:56,970 : INFO : PROGRESS: at sentence #3070000, processed 29719759 words, keeping 775785 word types
# 2019-08-14 07:13:57,039 : INFO : PROGRESS: at sentence #3080000, processed 29815301 words, keeping 777270 word types
# 2019-08-14 07:13:57,109 : INFO : PROGRESS: at sentence #3090000, processed 29910863 words, keeping 778767 word types
# 2019-08-14 07:13:57,178 : INFO : PROGRESS: at sentence #3100000, processed 30004685 words, keeping 780165 word types
# 2019-08-14 07:13:57,252 : INFO : PROGRESS: at sentence #3110000, processed 30100515 words, keeping 781693 word types
# 2019-08-14 07:13:57,318 : INFO : PROGRESS: at sentence #3120000, processed 30196415 words, keeping 783082 word types
# 2019-08-14 07:13:57,390 : INFO : PROGRESS: at sentence #3130000, processed 30293577 words, keeping 784512 word types
# 2019-08-14 07:13:57,461 : INFO : PROGRESS: at sentence #3140000, processed 30390471 words, keeping 785967 word types
# 2019-08-14 07:13:57,533 : INFO : PROGRESS: at sentence #3150000, processed 30486742 words, keeping 787407 word types
# 2019-08-14 07:13:57,605 : INFO : PROGRESS: at sentence #3160000, processed 30581144 words, keeping 788784 word types
# 2019-08-14 07:13:57,680 : INFO : PROGRESS: at sentence #3170000, processed 30677202 words, keeping 790262 word types
# 2019-08-14 07:13:57,753 : INFO : PROGRESS: at sentence #3180000, processed 30772569 words, keeping 791684 word types
# 2019-08-14 07:13:57,821 : INFO : PROGRESS: at sentence #3190000, processed 30868313 words, keeping 793098 word types
# 2019-08-14 07:13:57,903 : INFO : PROGRESS: at sentence #3200000, processed 30964347 words, keeping 794499 word types
# 2019-08-14 07:13:57,970 : INFO : PROGRESS: at sentence #3210000, processed 31060647 words, keeping 795869 word types
# 2019-08-14 07:13:58,053 : INFO : PROGRESS: at sentence #3220000, processed 31159239 words, keeping 797238 word types
# 2019-08-14 07:13:58,124 : INFO : PROGRESS: at sentence #3230000, processed 31259250 words, keeping 798684 word types
# 2019-08-14 07:13:58,200 : INFO : PROGRESS: at sentence #3240000, processed 31356908 words, keeping 800182 word types
# 2019-08-14 07:13:58,271 : INFO : PROGRESS: at sentence #3250000, processed 31456675 words, keeping 801574 word types
# 2019-08-14 07:13:58,352 : INFO : PROGRESS: at sentence #3260000, processed 31555373 words, keeping 802983 word types
# 2019-08-14 07:13:58,425 : INFO : PROGRESS: at sentence #3270000, processed 31654848 words, keeping 804398 word types
# 2019-08-14 07:13:58,494 : INFO : PROGRESS: at sentence #3280000, processed 31755249 words, keeping 805744 word types
# 2019-08-14 07:13:58,575 : INFO : PROGRESS: at sentence #3290000, processed 31853118 words, keeping 807017 word types
# 2019-08-14 07:13:58,643 : INFO : PROGRESS: at sentence #3300000, processed 31951853 words, keeping 808239 word types
# 2019-08-14 07:13:58,724 : INFO : PROGRESS: at sentence #3310000, processed 32046885 words, keeping 809518 word types
# 2019-08-14 07:13:58,790 : INFO : PROGRESS: at sentence #3320000, processed 32142284 words, keeping 810657 word types
# 2019-08-14 07:13:58,874 : INFO : PROGRESS: at sentence #3330000, processed 32238175 words, keeping 811841 word types
# 2019-08-14 07:13:58,943 : INFO : PROGRESS: at sentence #3340000, processed 32335251 words, keeping 813205 word types
# 2019-08-14 07:13:59,027 : INFO : PROGRESS: at sentence #3350000, processed 32431834 words, keeping 814617 word types
# 2019-08-14 07:13:59,098 : INFO : PROGRESS: at sentence #3360000, processed 32527890 words, keeping 816062 word types
# 2019-08-14 07:13:59,176 : INFO : PROGRESS: at sentence #3370000, processed 32623186 words, keeping 817513 word types
# 2019-08-14 07:13:59,248 : INFO : PROGRESS: at sentence #3380000, processed 32721277 words, keeping 818954 word types
# 2019-08-14 07:13:59,330 : INFO : PROGRESS: at sentence #3390000, processed 32817895 words, keeping 820430 word types
# 2019-08-14 07:13:59,401 : INFO : PROGRESS: at sentence #3400000, processed 32913747 words, keeping 821819 word types
# 2019-08-14 07:13:59,484 : INFO : PROGRESS: at sentence #3410000, processed 33009860 words, keeping 823194 word types
# 2019-08-14 07:13:59,555 : INFO : PROGRESS: at sentence #3420000, processed 33106279 words, keeping 824548 word types
# 2019-08-14 07:13:59,633 : INFO : PROGRESS: at sentence #3430000, processed 33203373 words, keeping 826002 word types
# 2019-08-14 07:13:59,706 : INFO : PROGRESS: at sentence #3440000, processed 33299395 words, keeping 827431 word types
# 2019-08-14 07:13:59,771 : INFO : PROGRESS: at sentence #3450000, processed 33395164 words, keeping 828841 word types
# 2019-08-14 07:13:59,858 : INFO : PROGRESS: at sentence #3460000, processed 33491374 words, keeping 830299 word types
# 2019-08-14 07:13:59,929 : INFO : PROGRESS: at sentence #3470000, processed 33587905 words, keeping 831761 word types
# 2019-08-14 07:14:00,001 : INFO : PROGRESS: at sentence #3480000, processed 33682753 words, keeping 833145 word types
# 2019-08-14 07:14:00,073 : INFO : PROGRESS: at sentence #3490000, processed 33779052 words, keeping 834501 word types
# 2019-08-14 07:14:00,149 : INFO : PROGRESS: at sentence #3500000, processed 33873760 words, keeping 835887 word types
# 2019-08-14 07:14:00,218 : INFO : PROGRESS: at sentence #3510000, processed 33968250 words, keeping 837203 word types
# 2019-08-14 07:14:00,293 : INFO : PROGRESS: at sentence #3520000, processed 34063168 words, keeping 838599 word types
# 2019-08-14 07:14:00,362 : INFO : PROGRESS: at sentence #3530000, processed 34158630 words, keeping 839944 word types
# 2019-08-14 07:14:00,444 : INFO : PROGRESS: at sentence #3540000, processed 34254914 words, keeping 841182 word types
# 2019-08-14 07:14:00,510 : INFO : PROGRESS: at sentence #3550000, processed 34347713 words, keeping 842537 word types
# 2019-08-14 07:14:00,584 : INFO : PROGRESS: at sentence #3560000, processed 34438798 words, keeping 843762 word types
# 2019-08-14 07:14:00,661 : INFO : PROGRESS: at sentence #3570000, processed 34531015 words, keeping 844977 word types
# 2019-08-14 07:14:00,727 : INFO : PROGRESS: at sentence #3580000, processed 34624100 words, keeping 846165 word types
# 2019-08-14 07:14:00,820 : INFO : PROGRESS: at sentence #3590000, processed 34719148 words, keeping 847374 word types
# 2019-08-14 07:14:00,895 : INFO : PROGRESS: at sentence #3600000, processed 34819053 words, keeping 848814 word types
# 2019-08-14 07:14:00,979 : INFO : PROGRESS: at sentence #3610000, processed 34918864 words, keeping 850243 word types
# 2019-08-14 07:14:01,047 : INFO : PROGRESS: at sentence #3620000, processed 35018239 words, keeping 851702 word types
# 2019-08-14 07:14:01,135 : INFO : PROGRESS: at sentence #3630000, processed 35117362 words, keeping 853081 word types
# 2019-08-14 07:14:01,205 : INFO : PROGRESS: at sentence #3640000, processed 35214049 words, keeping 854494 word types
# 2019-08-14 07:14:01,289 : INFO : PROGRESS: at sentence #3650000, processed 35313205 words, keeping 855942 word types
# 2019-08-14 07:14:01,359 : INFO : PROGRESS: at sentence #3660000, processed 35411339 words, keeping 857369 word types
# 2019-08-14 07:14:01,444 : INFO : PROGRESS: at sentence #3670000, processed 35508648 words, keeping 858733 word types
# 2019-08-14 07:14:01,517 : INFO : PROGRESS: at sentence #3680000, processed 35606505 words, keeping 860065 word types
# 2019-08-14 07:14:01,590 : INFO : PROGRESS: at sentence #3690000, processed 35704877 words, keeping 861550 word types
# 2019-08-14 07:14:01,661 : INFO : PROGRESS: at sentence #3700000, processed 35802976 words, keeping 863024 word types
# 2019-08-14 07:14:01,747 : INFO : PROGRESS: at sentence #3710000, processed 35901476 words, keeping 864385 word types
# 2019-08-14 07:14:01,816 : INFO : PROGRESS: at sentence #3720000, processed 35998663 words, keeping 865763 word types
# 2019-08-14 07:14:01,887 : INFO : PROGRESS: at sentence #3730000, processed 36096517 words, keeping 867106 word types
# 2019-08-14 07:14:01,965 : INFO : PROGRESS: at sentence #3740000, processed 36195368 words, keeping 868432 word types
# 2019-08-14 07:14:02,038 : INFO : PROGRESS: at sentence #3750000, processed 36293265 words, keeping 869829 word types
# 2019-08-14 07:14:02,116 : INFO : PROGRESS: at sentence #3760000, processed 36390447 words, keeping 871275 word types
# 2019-08-14 07:14:02,190 : INFO : PROGRESS: at sentence #3770000, processed 36488557 words, keeping 872745 word types
# 2019-08-14 07:14:02,268 : INFO : PROGRESS: at sentence #3780000, processed 36585933 words, keeping 874107 word types
# 2019-08-14 07:14:02,336 : INFO : PROGRESS: at sentence #3790000, processed 36683527 words, keeping 875445 word types
# 2019-08-14 07:14:02,422 : INFO : PROGRESS: at sentence #3800000, processed 36780946 words, keeping 876858 word types
# 2019-08-14 07:14:02,492 : INFO : PROGRESS: at sentence #3810000, processed 36877613 words, keeping 878173 word types
# 2019-08-14 07:14:02,574 : INFO : PROGRESS: at sentence #3820000, processed 36974531 words, keeping 879621 word types
# 2019-08-14 07:14:02,643 : INFO : PROGRESS: at sentence #3830000, processed 37071217 words, keeping 880976 word types
# 2019-08-14 07:14:02,725 : INFO : PROGRESS: at sentence #3840000, processed 37166259 words, keeping 882331 word types
# 2019-08-14 07:14:02,794 : INFO : PROGRESS: at sentence #3850000, processed 37261455 words, keeping 883706 word types
# 2019-08-14 07:14:02,876 : INFO : PROGRESS: at sentence #3860000, processed 37355478 words, keeping 884992 word types
# 2019-08-14 07:14:02,943 : INFO : PROGRESS: at sentence #3870000, processed 37448834 words, keeping 886322 word types
# 2019-08-14 07:14:03,019 : INFO : PROGRESS: at sentence #3880000, processed 37550307 words, keeping 887704 word types
# 2019-08-14 07:14:03,100 : INFO : PROGRESS: at sentence #3890000, processed 37653816 words, keeping 889013 word types
# 2019-08-14 07:14:03,185 : INFO : PROGRESS: at sentence #3900000, processed 37757912 words, keeping 890154 word types
# 2019-08-14 07:14:03,260 : INFO : PROGRESS: at sentence #3910000, processed 37862272 words, keeping 891472 word types
# 2019-08-14 07:14:03,348 : INFO : PROGRESS: at sentence #3920000, processed 37967558 words, keeping 892634 word types
# 2019-08-14 07:14:03,421 : INFO : PROGRESS: at sentence #3930000, processed 38069119 words, keeping 893731 word types
# 2019-08-14 07:14:03,506 : INFO : PROGRESS: at sentence #3940000, processed 38169968 words, keeping 894760 word types
# 2019-08-14 07:14:03,578 : INFO : PROGRESS: at sentence #3950000, processed 38269117 words, keeping 895888 word types
# 2019-08-14 07:14:03,662 : INFO : PROGRESS: at sentence #3960000, processed 38369673 words, keeping 897077 word types
# 2019-08-14 07:14:03,733 : INFO : PROGRESS: at sentence #3970000, processed 38467858 words, keeping 898232 word types
# 2019-08-14 07:14:03,802 : INFO : PROGRESS: at sentence #3980000, processed 38564787 words, keeping 899473 word types
# 2019-08-14 07:14:03,883 : INFO : PROGRESS: at sentence #3990000, processed 38663448 words, keeping 900655 word types
# 2019-08-14 07:14:03,955 : INFO : PROGRESS: at sentence #4000000, processed 38762829 words, keeping 902009 word types
# 2019-08-14 07:14:04,033 : INFO : PROGRESS: at sentence #4010000, processed 38862253 words, keeping 903371 word types
# 2019-08-14 07:14:04,106 : INFO : PROGRESS: at sentence #4020000, processed 38963048 words, keeping 904761 word types
# 2019-08-14 07:14:04,186 : INFO : PROGRESS: at sentence #4030000, processed 39063832 words, keeping 906093 word types
# 2019-08-14 07:14:04,255 : INFO : PROGRESS: at sentence #4040000, processed 39165303 words, keeping 907538 word types
# 2019-08-14 07:14:04,336 : INFO : PROGRESS: at sentence #4050000, processed 39266308 words, keeping 908965 word types
# 2019-08-14 07:14:04,412 : INFO : PROGRESS: at sentence #4060000, processed 39368593 words, keeping 910358 word types
# 2019-08-14 07:14:04,493 : INFO : PROGRESS: at sentence #4070000, processed 39470227 words, keeping 911775 word types
# 2019-08-14 07:14:04,571 : INFO : PROGRESS: at sentence #4080000, processed 39573294 words, keeping 913089 word types
# 2019-08-14 07:14:04,646 : INFO : PROGRESS: at sentence #4090000, processed 39673985 words, keeping 914436 word types
# 2019-08-14 07:14:04,724 : INFO : PROGRESS: at sentence #4100000, processed 39776334 words, keeping 915782 word types
# ...
# 2019-08-14 07:48:21,073 : INFO : EPOCH 5 - PROGRESS: at 74.25% examples, 370963 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:22,101 : INFO : EPOCH 5 - PROGRESS: at 74.51% examples, 370883 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:23,120 : INFO : EPOCH 5 - PROGRESS: at 74.78% examples, 370869 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:24,121 : INFO : EPOCH 5 - PROGRESS: at 75.04% examples, 370846 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:25,168 : INFO : EPOCH 5 - PROGRESS: at 75.30% examples, 370697 words/s, in_qsize 5, out_qsize 2
# 2019-08-14 07:48:26,205 : INFO : EPOCH 5 - PROGRESS: at 75.59% examples, 370731 words/s, in_qsize 7, out_qsize 0
# 2019-08-14 07:48:27,210 : INFO : EPOCH 5 - PROGRESS: at 75.84% examples, 370654 words/s, in_qsize 7, out_qsize 0
# 2019-08-14 07:48:28,244 : INFO : EPOCH 5 - PROGRESS: at 76.00% examples, 370081 words/s, in_qsize 8, out_qsize 0
# 2019-08-14 07:48:29,269 : INFO : EPOCH 5 - PROGRESS: at 76.24% examples, 369948 words/s, in_qsize 7, out_qsize 0
# 2019-08-14 07:48:30,281 : INFO : EPOCH 5 - PROGRESS: at 76.50% examples, 369889 words/s, in_qsize 1, out_qsize 0
# 2019-08-14 07:48:31,292 : INFO : EPOCH 5 - PROGRESS: at 76.78% examples, 370001 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:32,293 : INFO : EPOCH 5 - PROGRESS: at 77.02% examples, 369898 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:33,304 : INFO : EPOCH 5 - PROGRESS: at 77.31% examples, 370005 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:34,318 : INFO : EPOCH 5 - PROGRESS: at 77.59% examples, 370080 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:35,329 : INFO : EPOCH 5 - PROGRESS: at 77.77% examples, 369743 words/s, in_qsize 1, out_qsize 0
# 2019-08-14 07:48:36,329 : INFO : EPOCH 5 - PROGRESS: at 78.02% examples, 369694 words/s, in_qsize 4, out_qsize 0
# 2019-08-14 07:48:37,448 : INFO : EPOCH 5 - PROGRESS: at 78.18% examples, 369030 words/s, in_qsize 0, out_qsize 2
# 2019-08-14 07:48:38,467 : INFO : EPOCH 5 - PROGRESS: at 78.44% examples, 368985 words/s, in_qsize 1, out_qsize 0
# 2019-08-14 07:48:39,468 : INFO : EPOCH 5 - PROGRESS: at 78.73% examples, 369047 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:40,491 : INFO : EPOCH 5 - PROGRESS: at 78.97% examples, 368874 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:41,509 : INFO : EPOCH 5 - PROGRESS: at 79.25% examples, 368925 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:42,519 : INFO : EPOCH 5 - PROGRESS: at 79.51% examples, 368909 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:43,530 : INFO : EPOCH 5 - PROGRESS: at 79.76% examples, 368792 words/s, in_qsize 1, out_qsize 0
# 2019-08-14 07:48:44,533 : INFO : EPOCH 5 - PROGRESS: at 80.01% examples, 368710 words/s, in_qsize 3, out_qsize 0
# 2019-08-14 07:48:45,550 : INFO : EPOCH 5 - PROGRESS: at 80.31% examples, 368828 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:46,567 : INFO : EPOCH 5 - PROGRESS: at 80.57% examples, 368792 words/s, in_qsize 2, out_qsize 0
# 2019-08-14 07:48:47,616 : INFO : EPOCH 5 - PROGRESS: at 80.73% examples, 368216 words/s, in_qsize 2, out_qsize 0
# 2019-08-14 07:48:48,626 : INFO : EPOCH 5 - PROGRESS: at 80.96% examples, 368041 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:49,631 : INFO : EPOCH 5 - PROGRESS: at 81.16% examples, 367744 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:50,664 : INFO : EPOCH 5 - PROGRESS: at 81.42% examples, 367724 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:51,689 : INFO : EPOCH 5 - PROGRESS: at 81.70% examples, 367834 words/s, in_qsize 4, out_qsize 0
# 2019-08-14 07:48:52,701 : INFO : EPOCH 5 - PROGRESS: at 81.98% examples, 367971 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:53,716 : INFO : EPOCH 5 - PROGRESS: at 82.25% examples, 368095 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:54,733 : INFO : EPOCH 5 - PROGRESS: at 82.52% examples, 368179 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:55,737 : INFO : EPOCH 5 - PROGRESS: at 82.77% examples, 368226 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:48:56,770 : INFO : EPOCH 5 - PROGRESS: at 83.02% examples, 368212 words/s, in_qsize 6, out_qsize 0
# 2019-08-14 07:48:57,891 : INFO : EPOCH 5 - PROGRESS: at 83.21% examples, 367830 words/s, in_qsize 7, out_qsize 0
# 2019-08-14 07:48:58,912 : INFO : EPOCH 5 - PROGRESS: at 83.47% examples, 367851 words/s, in_qsize 5, out_qsize 0
# 2019-08-14 07:48:59,941 : INFO : EPOCH 5 - PROGRESS: at 83.77% examples, 368017 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:00,959 : INFO : EPOCH 5 - PROGRESS: at 84.02% examples, 367968 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:01,967 : INFO : EPOCH 5 - PROGRESS: at 84.28% examples, 368001 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:02,988 : INFO : EPOCH 5 - PROGRESS: at 84.53% examples, 367932 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:03,994 : INFO : EPOCH 5 - PROGRESS: at 84.81% examples, 368019 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:05,021 : INFO : EPOCH 5 - PROGRESS: at 85.07% examples, 368003 words/s, in_qsize 1, out_qsize 1
# 2019-08-14 07:49:06,038 : INFO : EPOCH 5 - PROGRESS: at 85.36% examples, 368147 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:07,064 : INFO : EPOCH 5 - PROGRESS: at 85.63% examples, 368208 words/s, in_qsize 7, out_qsize 0
# 2019-08-14 07:49:08,067 : INFO : EPOCH 5 - PROGRESS: at 85.80% examples, 367818 words/s, in_qsize 5, out_qsize 0
# 2019-08-14 07:49:09,074 : INFO : EPOCH 5 - PROGRESS: at 86.09% examples, 367993 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:10,086 : INFO : EPOCH 5 - PROGRESS: at 86.36% examples, 368076 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:11,102 : INFO : EPOCH 5 - PROGRESS: at 86.65% examples, 368190 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:12,111 : INFO : EPOCH 5 - PROGRESS: at 86.92% examples, 368300 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:13,113 : INFO : EPOCH 5 - PROGRESS: at 87.18% examples, 368393 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:14,114 : INFO : EPOCH 5 - PROGRESS: at 87.44% examples, 368456 words/s, in_qsize 5, out_qsize 0
# 2019-08-14 07:49:15,141 : INFO : EPOCH 5 - PROGRESS: at 87.72% examples, 368590 words/s, in_qsize 6, out_qsize 1
# 2019-08-14 07:49:16,158 : INFO : EPOCH 5 - PROGRESS: at 88.02% examples, 368780 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:17,187 : INFO : EPOCH 5 - PROGRESS: at 88.23% examples, 368567 words/s, in_qsize 5, out_qsize 1
# 2019-08-14 07:49:18,200 : INFO : EPOCH 5 - PROGRESS: at 88.52% examples, 368679 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:19,205 : INFO : EPOCH 5 - PROGRESS: at 88.79% examples, 368729 words/s, in_qsize 4, out_qsize 1
# 2019-08-14 07:49:20,211 : INFO : EPOCH 5 - PROGRESS: at 89.07% examples, 368811 words/s, in_qsize 6, out_qsize 1
# 2019-08-14 07:49:21,216 : INFO : EPOCH 5 - PROGRESS: at 89.35% examples, 368918 words/s, in_qsize 4, out_qsize 0
# 2019-08-14 07:49:22,233 : INFO : EPOCH 5 - PROGRESS: at 89.64% examples, 369096 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:23,636 : INFO : EPOCH 5 - PROGRESS: at 89.88% examples, 368669 words/s, in_qsize 4, out_qsize 0
# 2019-08-14 07:49:24,646 : INFO : EPOCH 5 - PROGRESS: at 90.14% examples, 368744 words/s, in_qsize 5, out_qsize 2
# 2019-08-14 07:49:25,652 : INFO : EPOCH 5 - PROGRESS: at 90.39% examples, 368815 words/s, in_qsize 6, out_qsize 0
# 2019-08-14 07:49:26,657 : INFO : EPOCH 5 - PROGRESS: at 90.68% examples, 369025 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:27,657 : INFO : EPOCH 5 - PROGRESS: at 90.96% examples, 369156 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:28,679 : INFO : EPOCH 5 - PROGRESS: at 91.25% examples, 369245 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:29,690 : INFO : EPOCH 5 - PROGRESS: at 91.54% examples, 369389 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:30,694 : INFO : EPOCH 5 - PROGRESS: at 91.80% examples, 369475 words/s, in_qsize 5, out_qsize 0
# 2019-08-14 07:49:31,706 : INFO : EPOCH 5 - PROGRESS: at 92.02% examples, 369389 words/s, in_qsize 5, out_qsize 0
# 2019-08-14 07:49:32,708 : INFO : EPOCH 5 - PROGRESS: at 92.33% examples, 369599 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:33,714 : INFO : EPOCH 5 - PROGRESS: at 92.60% examples, 369680 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:34,735 : INFO : EPOCH 5 - PROGRESS: at 92.88% examples, 369792 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:35,736 : INFO : EPOCH 5 - PROGRESS: at 93.14% examples, 369841 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:36,755 : INFO : EPOCH 5 - PROGRESS: at 93.40% examples, 369910 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:37,764 : INFO : EPOCH 5 - PROGRESS: at 93.68% examples, 370004 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:38,766 : INFO : EPOCH 5 - PROGRESS: at 93.95% examples, 370058 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:39,780 : INFO : EPOCH 5 - PROGRESS: at 94.22% examples, 370120 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:40,793 : INFO : EPOCH 5 - PROGRESS: at 94.49% examples, 370206 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:41,800 : INFO : EPOCH 5 - PROGRESS: at 94.76% examples, 370294 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:42,808 : INFO : EPOCH 5 - PROGRESS: at 95.02% examples, 370374 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:43,817 : INFO : EPOCH 5 - PROGRESS: at 95.22% examples, 370227 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:44,828 : INFO : EPOCH 5 - PROGRESS: at 95.41% examples, 370080 words/s, in_qsize 0, out_qsize 1
# 2019-08-14 07:49:45,846 : INFO : EPOCH 5 - PROGRESS: at 95.63% examples, 369944 words/s, in_qsize 6, out_qsize 1
# 2019-08-14 07:49:46,863 : INFO : EPOCH 5 - PROGRESS: at 95.88% examples, 369962 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:47,866 : INFO : EPOCH 5 - PROGRESS: at 96.12% examples, 369902 words/s, in_qsize 6, out_qsize 0
# 2019-08-14 07:49:48,884 : INFO : EPOCH 5 - PROGRESS: at 96.40% examples, 369969 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:49,888 : INFO : EPOCH 5 - PROGRESS: at 96.63% examples, 369894 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:50,891 : INFO : EPOCH 5 - PROGRESS: at 96.86% examples, 369838 words/s, in_qsize 5, out_qsize 0
# 2019-08-14 07:49:51,930 : INFO : EPOCH 5 - PROGRESS: at 97.15% examples, 369971 words/s, in_qsize 0, out_qsize 1
# 2019-08-14 07:49:52,935 : INFO : EPOCH 5 - PROGRESS: at 97.39% examples, 369931 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:53,949 : INFO : EPOCH 5 - PROGRESS: at 97.64% examples, 369942 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:54,955 : INFO : EPOCH 5 - PROGRESS: at 97.72% examples, 369296 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:49:55,969 : INFO : EPOCH 5 - PROGRESS: at 97.94% examples, 369198 words/s, in_qsize 2, out_qsize 0
# 2019-08-14 07:49:56,975 : INFO : EPOCH 5 - PROGRESS: at 98.18% examples, 369167 words/s, in_qsize 1, out_qsize 0
# 2019-08-14 07:49:57,985 : INFO : EPOCH 5 - PROGRESS: at 98.44% examples, 369216 words/s, in_qsize 6, out_qsize 1
# 2019-08-14 07:49:58,986 : INFO : EPOCH 5 - PROGRESS: at 98.72% examples, 369337 words/s, in_qsize 6, out_qsize 0
# 2019-08-14 07:49:59,992 : INFO : EPOCH 5 - PROGRESS: at 99.00% examples, 369481 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:50:01,009 : INFO : EPOCH 5 - PROGRESS: at 99.27% examples, 369557 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:50:02,028 : INFO : EPOCH 5 - PROGRESS: at 99.53% examples, 369599 words/s, in_qsize 0, out_qsize 0
# 2019-08-14 07:50:03,060 : INFO : EPOCH 5 - PROGRESS: at 99.83% examples, 369725 words/s, in_qsize 7, out_qsize 0
# 2019-08-14 07:50:03,703 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-08-14 07:50:03,713 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-08-14 07:50:03,728 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-08-14 07:50:03,734 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-08-14 07:50:03,735 : INFO : EPOCH - 5 : training on 173212741 raw words (140585496 effective words) took 380.3s, 369685 effective words/s
# 2019-08-14 07:50:03,772 : INFO : training on a 866063705 raw words (702928234 effective words) took 2037.1s, 345067 effective words/s
# 2019-08-14 07:50:03,911 : INFO : saving Word2Vec object under models/w2v/model.w2v, separately None
# 2019-08-14 07:50:03,914 : INFO : storing np array 'vectors' to models/w2v/model.w2v.wv.vectors.npy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/gensim/utils.py in save(self, fname_or_handle, separately, sep_limit, ignore, pickle_protocol)
#     681         try:
# --> 682             _pickle.dump(self, fname_or_handle, protocol=pickle_protocol)
#     683             logger.info("saved %s object", self.__class__.__name__)
#
# TypeError: file must have a 'write' attribute
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-86e568dec289> in <module>()
#       9 # Обучаем модель
#      10 model = Word2Vec(data, size=200, window=5, min_count=3, workers=multiprocessing.cpu_count())
# ---> 11 model.save("models/w2v/model.w2v")
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/gensim/models/word2vec.py in save(self, *args, **kwargs)
#    1248         # don't bother storing the cached normalized vectors, recalculable table
#    1249         kwargs['ignore'] = kwargs.get('ignore', ['vectors_norm', 'cum_table'])
# -> 1250         super(Word2Vec, self).save(*args, **kwargs)
#    1251
#    1252     def get_latest_training_loss(self):
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/gensim/models/base_any2vec.py in save(self, fname_or_handle, **kwargs)
#     619
#     620         """
# --> 621         super(BaseAny2VecModel, self).save(fname_or_handle, **kwargs)
#     622
#     623
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/gensim/utils.py in save(self, fname_or_handle, separately, sep_limit, ignore, pickle_protocol)
#     683             logger.info("saved %s object", self.__class__.__name__)
#     684         except TypeError:  # `fname_or_handle` does not have write attribute
# --> 685             self._smart_save(fname_or_handle, separately, sep_limit, ignore, pickle_protocol=pickle_protocol)
#     686
#     687
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/gensim/utils.py in _smart_save(self, fname, separately, sep_limit, ignore, pickle_protocol)
#     537
#     538         restores = self._save_specials(fname, separately, sep_limit, ignore, pickle_protocol,
# --> 539                                        compress, subname)
#     540         try:
#     541             pickle(self, fname, protocol=pickle_protocol)
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/gensim/utils.py in _save_specials(self, fname, separately, sep_limit, ignore, pickle_protocol, compress, subname)
#     597                 recursive_saveloads.append(attrib)
#     598                 cfname = '.'.join((fname, attrib))
# --> 599                 restores.extend(val._save_specials(cfname, None, sep_limit, ignore, pickle_protocol, compress, subname))
#     600
#     601         try:
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/gensim/utils.py in _save_specials(self, fname, separately, sep_limit, ignore, pickle_protocol, compress, subname)
#     609                         np.savez_compressed(subname(fname, attrib), val=np.ascontiguousarray(val))
#     610                     else:
# --> 611                         np.save(subname(fname, attrib), np.ascontiguousarray(val))
#     612
#     613                 elif isinstance(val, (scipy.sparse.csr_matrix, scipy.sparse.csc_matrix)) and attrib not in ignore:
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     522         if not file.endswith('.npy'):
#     523             file = file + '.npy'
# --> 524         fid = open(file, "wb")
#     525         own_fid = True
#     526
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/w2v/model.w2v.wv.vectors.npy'

# %%
model.save("models/w2v/model.w2v")
# Out:
# 2019-08-14 07:56:41,659 : INFO : saving Word2Vec object under models/w2v/model.w2v, separately None
# 2019-08-14 07:56:41,665 : INFO : storing np array 'vectors' to models/w2v/model.w2v.wv.vectors.npy
# 2019-08-14 07:56:45,115 : INFO : not storing attribute vectors_norm
# 2019-08-14 07:56:45,121 : INFO : storing np array 'syn1neg' to models/w2v/model.w2v.trainables.syn1neg.npy
# 2019-08-14 07:56:53,674 : INFO : saved models/w2v/model.w2v

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# Высота матрицы (максимальное количество слов в твите)
SENTENCE_LENGTH = 26
# Размер словаря
NUM = 100000

def get_sequences(tokenizer, x):
    sequences = tokenizer.texts_to_sequences(x)
    return pad_sequences(sequences, maxlen=SENTENCE_LENGTH)

# Cоздаем и обучаем токенизатор
tokenizer = Tokenizer(num_words=NUM)
tokenizer.fit_on_texts(x_train)

# Отображаем каждый текст в массив идентификаторов токенов
x_train_seq = get_sequences(tokenizer, x_train)
x_test_seq = get_sequences(tokenizer, x_test)
# Out:
# /Users/anastasiazuhba/anaconda3/envs/Py3ML/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from gensim.models import Word2Vec
# Загружаем обученную модель
w2v_model = Word2Vec.load('models/w2v/model.w2v')
DIM = w2v_model.vector_size 
# Инициализируем матрицу embedding слоя нулями
embedding_matrix = np.zeros((NUM, DIM))
# Добавляем NUM=100000 наиболее часто встречающихся слов из обучающей выборки в embedding слой
for word, i in tokenizer.word_index.items():
    if i >= NUM:
        break
    if word in w2v_model.wv.vocab.keys():
        embedding_matrix[i] = w2v_model.wv[word]
# Out:
# 2019-08-14 08:00:20,252 : INFO : loading Word2Vec object from models/w2v/model.w2v
# 2019-08-14 08:00:25,078 : INFO : loading wv recursively from models/w2v/model.w2v.wv.* with mmap=None
# 2019-08-14 08:00:25,080 : INFO : loading vectors from models/w2v/model.w2v.wv.vectors.npy with mmap=None
# 2019-08-14 08:00:28,270 : INFO : setting ignored attribute vectors_norm to None
# 2019-08-14 08:00:28,301 : INFO : loading vocabulary recursively from models/w2v/model.w2v.vocabulary.* with mmap=None
# 2019-08-14 08:00:28,304 : INFO : loading trainables recursively from models/w2v/model.w2v.trainables.* with mmap=None
# 2019-08-14 08:00:28,308 : INFO : loading syn1neg from models/w2v/model.w2v.trainables.syn1neg.npy with mmap=None
# 2019-08-14 08:00:33,061 : INFO : loaded models/w2v/model.w2v

# %%
from keras import backend as K


def precision(y_true, y_pred):
    """Precision metric.

    Only computes a batch-wise average of precision.

    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    """Recall metric.

    Only computes a batch-wise average of recall.

    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall


def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# %% [markdown]
# #### Свёрточная нейронная сеть

# %%
from keras.layers import Input
from keras.layers.embeddings import Embedding

tweet_input = Input(shape=(SENTENCE_LENGTH,), dtype='int32')
tweet_encoder = Embedding(NUM, DIM, input_length=SENTENCE_LENGTH,
                          weights=[embedding_matrix], trainable=False)(tweet_input)

# %%
from keras import optimizers
from keras.layers import Dense, concatenate, Activation, Dropout
from keras.models import Model
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import GlobalMaxPooling1D

branches = []
# Добавляем dropout-регуляризацию
x = Dropout(0.2)(tweet_encoder)

for size, filters_count in [(2, 10), (3, 10), (4, 10), (5, 10)]:
    for i in range(filters_count):
        # Добавляем слой свертки
        branch = Conv1D(filters=1, kernel_size=size, padding='valid', activation='relu')(x)
        # Добавляем слой субдискретизации
        branch = GlobalMaxPooling1D()(branch)
        branches.append(branch)
# Конкатенируем карты признаков
x = concatenate(branches, axis=1)
# Добавляем dropout-регуляризацию
x = Dropout(0.2)(x)
x = Dense(30, activation='relu')(x)
x = Dense(1)(x)
output = Activation('sigmoid')(x)

model = Model(inputs=[tweet_input], outputs=[output])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[precision, recall, f1])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 26)           0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 26, 200)      20000000    input_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 26, 200)      0           embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_41 (Global (None, 1)            0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_42 (Global (None, 1)            0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_43 (Global (None, 1)            0           conv1d_43[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_44 (Global (None, 1)            0           conv1d_44[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_45 (Global (None, 1)            0           conv1d_45[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_46 (Global (None, 1)            0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_47 (Global (None, 1)            0           conv1d_47[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_48 (Global (None, 1)            0           conv1d_48[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_49 (Global (None, 1)            0           conv1d_49[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_50 (Global (None, 1)            0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_51 (Global (None, 1)            0           conv1d_51[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_52 (Global (None, 1)            0           conv1d_52[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_53 (Global (None, 1)            0           conv1d_53[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_54 (Global (None, 1)            0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_55 (Global (None, 1)            0           conv1d_55[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_56 (Global (None, 1)            0           conv1d_56[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_57 (Global (None, 1)            0           conv1d_57[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_58 (Global (None, 1)            0           conv1d_58[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_59 (Global (None, 1)            0           conv1d_59[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_60 (Global (None, 1)            0           conv1d_60[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_61 (Global (None, 1)            0           conv1d_61[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_62 (Global (None, 1)            0           conv1d_62[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_63 (Global (None, 1)            0           conv1d_63[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_64 (Global (None, 1)            0           conv1d_64[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_65 (Global (None, 1)            0           conv1d_65[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_66 (Global (None, 1)            0           conv1d_66[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_67 (Global (None, 1)            0           conv1d_67[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_68 (Global (None, 1)            0           conv1d_68[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_69 (Global (None, 1)            0           conv1d_69[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_70 (Global (None, 1)            0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_71 (Global (None, 1)            0           conv1d_71[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_72 (Global (None, 1)            0           conv1d_72[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_73 (Global (None, 1)            0           conv1d_73[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_74 (Global (None, 1)            0           conv1d_74[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_75 (Global (None, 1)            0           conv1d_75[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_76 (Global (None, 1)            0           conv1d_76[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_77 (Global (None, 1)            0           conv1d_77[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_78 (Global (None, 1)            0           conv1d_78[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_79 (Global (None, 1)            0           conv1d_79[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_80 (Global (None, 1)            0           conv1d_80[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 40)           0           global_max_pooling1d_41[0][0]
#                                                                  global_max_pooling1d_42[0][0]
#                                                                  global_max_pooling1d_43[0][0]
#                                                                  global_max_pooling1d_44[0][0]
#                                                                  global_max_pooling1d_45[0][0]
#                                                                  global_max_pooling1d_46[0][0]
#                                                                  global_max_pooling1d_47[0][0]
#                                                                  global_max_pooling1d_48[0][0]
#                                                                  global_max_pooling1d_49[0][0]
#                                                                  global_max_pooling1d_50[0][0]
#                                                                  global_max_pooling1d_51[0][0]
#                                                                  global_max_pooling1d_52[0][0]
#                                                                  global_max_pooling1d_53[0][0]
#                                                                  global_max_pooling1d_54[0][0]
#                                                                  global_max_pooling1d_55[0][0]
#                                                                  global_max_pooling1d_56[0][0]
#                                                                  global_max_pooling1d_57[0][0]
#                                                                  global_max_pooling1d_58[0][0]
#                                                                  global_max_pooling1d_59[0][0]
#                                                                  global_max_pooling1d_60[0][0]
#                                                                  global_max_pooling1d_61[0][0]
#                                                                  global_max_pooling1d_62[0][0]
#                                                                  global_max_pooling1d_63[0][0]
#                                                                  global_max_pooling1d_64[0][0]
#                                                                  global_max_pooling1d_65[0][0]
#                                                                  global_max_pooling1d_66[0][0]
#                                                                  global_max_pooling1d_67[0][0]
#                                                                  global_max_pooling1d_68[0][0]
#                                                                  global_max_pooling1d_69[0][0]
#                                                                  global_max_pooling1d_70[0][0]
#                                                                  global_max_pooling1d_71[0][0]
#                                                                  global_max_pooling1d_72[0][0]
#                                                                  global_max_pooling1d_73[0][0]
#                                                                  global_max_pooling1d_74[0][0]
#                                                                  global_max_pooling1d_75[0][0]
#                                                                  global_max_pooling1d_76[0][0]
#                                                                  global_max_pooling1d_77[0][0]
#                                                                  global_max_pooling1d_78[0][0]
#                                                                  global_max_pooling1d_79[0][0]
#                                                                  global_max_pooling1d_80[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 40)           0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           1230        dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            31          dense_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 20,029,301
# Trainable params: 29,301
# Non-trainable params: 20,000,000
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("models/cnn/cnn-frozen-embeddings-{epoch:02d}-{val_f1:.2f}.hdf5", monitor='val_f1', save_best_only=True, mode='max', period=1)
history = model.fit(x_train_seq, y_train, batch_size=32, epochs=10, validation_split=0.25, callbacks = [checkpoint])
# Out:
# Train on 134307 samples, validate on 44769 samples
# Epoch 1/10
# 134307/134307 [==============================] - 385s 3ms/step - loss: 0.5719 - precision: 0.6992 - recall: 0.6937 - f1: 0.6874 - val_loss: 0.5082 - val_precision: 0.7167 - val_recall: 0.8122 - val_f1: 0.7558
# Epoch 2/10
# 134307/134307 [==============================] - 366s 3ms/step - loss: 0.5170 - precision: 0.7411 - recall: 0.7315 - f1: 0.7288 - val_loss: 0.4887 - val_precision: 0.7639 - val_recall: 0.7484 - val_f1: 0.7496
# Epoch 3/10
# 134307/134307 [==============================] - 354s 3ms/step - loss: 0.5038 - precision: 0.7496 - recall: 0.7403 - f1: 0.7376 - val_loss: 0.4860 - val_precision: 0.7972 - val_recall: 0.6951 - val_f1: 0.7358
# Epoch 4/10
# 134307/134307 [==============================] - 348s 3ms/step - loss: 0.4965 - precision: 0.7548 - recall: 0.7438 - f1: 0.7422 - val_loss: 0.4806 - val_precision: 0.7542 - val_recall: 0.7838 - val_f1: 0.7631
# Epoch 5/10
# 134307/134307 [==============================] - 356s 3ms/step - loss: 0.4902 - precision: 0.7586 - recall: 0.7509 - f1: 0.7477 - val_loss: 0.4777 - val_precision: 0.7749 - val_recall: 0.7486 - val_f1: 0.7553
# Epoch 6/10
# 134307/134307 [==============================] - 371s 3ms/step - loss: 0.4852 - precision: 0.7619 - recall: 0.7520 - f1: 0.7502 - val_loss: 0.4793 - val_precision: 0.7534 - val_recall: 0.7914 - val_f1: 0.7664
# Epoch 7/10
# 134307/134307 [==============================] - 353s 3ms/step - loss: 0.4807 - precision: 0.7657 - recall: 0.7536 - f1: 0.7531 - val_loss: 0.4751 - val_precision: 0.7734 - val_recall: 0.7613 - val_f1: 0.7612
# Epoch 8/10
# 134307/134307 [==============================] - 350s 3ms/step - loss: 0.4782 - precision: 0.7654 - recall: 0.7567 - f1: 0.7544 - val_loss: 0.4789 - val_precision: 0.8041 - val_recall: 0.7041 - val_f1: 0.7442
# Epoch 9/10
# 134307/134307 [==============================] - 352s 3ms/step - loss: 0.4741 - precision: 0.7691 - recall: 0.7603 - f1: 0.7582 - val_loss: 0.4740 - val_precision: 0.7723 - val_recall: 0.7655 - val_f1: 0.7630
# Epoch 10/10
# 134307/134307 [==============================] - 357s 3ms/step - loss: 0.4735 - precision: 0.7667 - recall: 0.7639 - f1: 0.7588 - val_loss: 0.4752 - val_precision: 0.7840 - val_recall: 0.7519 - val_f1: 0.7614

# %% [markdown]
# Затем выбираем модель с наивысшими показателями F-меры на валидационном наборе данных, т.е. модель, полученную на восьмой эпохе обучения. У модели разморозил embedding-слой, после чего запустил еще пять эпох обучения.

# %%
from keras import optimizers
# Загружаем веса модели
model.load_weights('models/cnn/cnn-frozen-embeddings-06-0.77.hdf5')
# Делаем embedding слой способным к обучению
model.layers[1].trainable = True
# Уменьшаем learning rate
adam = optimizers.Adam(lr=0.0001)
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=[precision, recall, f1])
model.summary()
 

checkpoint = ModelCheckpoint("models/cnn/cnn-trainable-{epoch:02d}-{val_f1:.2f}.hdf5", monitor='val_f1', save_best_only=True, mode='max', period=1)

history_trainable = model.fit(x_train_seq, y_train, batch_size=32, epochs=5, validation_split=0.25, callbacks = [checkpoint])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 26)           0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 26, 200)      20000000    input_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 26, 200)      0           embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 25, 1)        401         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 24, 1)        601         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 23, 1)        801         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 22, 1)        1001        dropout_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_41 (Global (None, 1)            0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_42 (Global (None, 1)            0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_43 (Global (None, 1)            0           conv1d_43[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_44 (Global (None, 1)            0           conv1d_44[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_45 (Global (None, 1)            0           conv1d_45[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_46 (Global (None, 1)            0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_47 (Global (None, 1)            0           conv1d_47[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_48 (Global (None, 1)            0           conv1d_48[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_49 (Global (None, 1)            0           conv1d_49[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_50 (Global (None, 1)            0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_51 (Global (None, 1)            0           conv1d_51[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_52 (Global (None, 1)            0           conv1d_52[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_53 (Global (None, 1)            0           conv1d_53[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_54 (Global (None, 1)            0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_55 (Global (None, 1)            0           conv1d_55[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_56 (Global (None, 1)            0           conv1d_56[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_57 (Global (None, 1)            0           conv1d_57[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_58 (Global (None, 1)            0           conv1d_58[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_59 (Global (None, 1)            0           conv1d_59[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_60 (Global (None, 1)            0           conv1d_60[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_61 (Global (None, 1)            0           conv1d_61[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_62 (Global (None, 1)            0           conv1d_62[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_63 (Global (None, 1)            0           conv1d_63[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_64 (Global (None, 1)            0           conv1d_64[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_65 (Global (None, 1)            0           conv1d_65[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_66 (Global (None, 1)            0           conv1d_66[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_67 (Global (None, 1)            0           conv1d_67[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_68 (Global (None, 1)            0           conv1d_68[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_69 (Global (None, 1)            0           conv1d_69[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_70 (Global (None, 1)            0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_71 (Global (None, 1)            0           conv1d_71[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_72 (Global (None, 1)            0           conv1d_72[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_73 (Global (None, 1)            0           conv1d_73[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_74 (Global (None, 1)            0           conv1d_74[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_75 (Global (None, 1)            0           conv1d_75[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_76 (Global (None, 1)            0           conv1d_76[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_77 (Global (None, 1)            0           conv1d_77[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_78 (Global (None, 1)            0           conv1d_78[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_79 (Global (None, 1)            0           conv1d_79[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_80 (Global (None, 1)            0           conv1d_80[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 40)           0           global_max_pooling1d_41[0][0]
#                                                                  global_max_pooling1d_42[0][0]
#                                                                  global_max_pooling1d_43[0][0]
#                                                                  global_max_pooling1d_44[0][0]
#                                                                  global_max_pooling1d_45[0][0]
#                                                                  global_max_pooling1d_46[0][0]
#                                                                  global_max_pooling1d_47[0][0]
#                                                                  global_max_pooling1d_48[0][0]
#                                                                  global_max_pooling1d_49[0][0]
#                                                                  global_max_pooling1d_50[0][0]
#                                                                  global_max_pooling1d_51[0][0]
#                                                                  global_max_pooling1d_52[0][0]
#                                                                  global_max_pooling1d_53[0][0]
#                                                                  global_max_pooling1d_54[0][0]
#                                                                  global_max_pooling1d_55[0][0]
#                                                                  global_max_pooling1d_56[0][0]
#                                                                  global_max_pooling1d_57[0][0]
#                                                                  global_max_pooling1d_58[0][0]
#                                                                  global_max_pooling1d_59[0][0]
#                                                                  global_max_pooling1d_60[0][0]
#                                                                  global_max_pooling1d_61[0][0]
#                                                                  global_max_pooling1d_62[0][0]
#                                                                  global_max_pooling1d_63[0][0]
#                                                                  global_max_pooling1d_64[0][0]
#                                                                  global_max_pooling1d_65[0][0]
#                                                                  global_max_pooling1d_66[0][0]
#                                                                  global_max_pooling1d_67[0][0]
#                                                                  global_max_pooling1d_68[0][0]
#                                                                  global_max_pooling1d_69[0][0]
#                                                                  global_max_pooling1d_70[0][0]
#                                                                  global_max_pooling1d_71[0][0]
#                                                                  global_max_pooling1d_72[0][0]
#                                                                  global_max_pooling1d_73[0][0]
#                                                                  global_max_pooling1d_74[0][0]
#                                                                  global_max_pooling1d_75[0][0]
#                                                                  global_max_pooling1d_76[0][0]
#                                                                  global_max_pooling1d_77[0][0]
#                                                                  global_max_pooling1d_78[0][0]
#                                                                  global_max_pooling1d_79[0][0]
#                                                                  global_max_pooling1d_80[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 40)           0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           1230        dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            31          dense_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 20,029,301
# Trainable params: 20,029,301
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 134307 samples, validate on 44769 samples
# Epoch 1/5
#   6112/134307 [>.............................] - ETA: 36:04 - loss: 0.4774 - precision: 0.7631 - recall: 0.7648 - f1: 0.7585
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-a9f13f666c06> in <module>()
#      12 checkpoint = ModelCheckpoint("models/cnn/cnn-trainable-{epoch:02d}-{val_f1:.2f}.hdf5", monitor='val_f1', save_best_only=True, mode='max', period=1)
#      13
# ---> 14 history_trainable = model.fit(x_train_seq, y_train, batch_size=32, epochs=5, validation_split=0.25, callbacks = [checkpoint])
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/Py3ML/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
